# %% [markdown]
# # Lesson 4: Constructing a Knowledge Graph from Text Documents

# %% [markdown]
# <p style="background-color:#fd4a6180; padding:15px; margin-left:20px"> <b>Note:</b> This notebook takes about 30 seconds to be ready to use. Please wait until the "Kernel starting, please wait..." message clears from the top of the notebook before running any cells. You may start the video while you wait.</p>

# %% [markdown]
# ### Import packages and set up Neo4j

# %%
from dotenv import load_dotenv
import os

# Common data processing
import json
import textwrap

# Langchain
from langchain_community.graphs import Neo4jGraph
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQAWithSourcesChain
from langchain_openai import ChatOpenAI


# Warning control
import warnings
warnings.filterwarnings("ignore")

# %%
# Load from environment
load_dotenv('.env', override=True)
NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_USERNAME = os.getenv('NEO4J_USERNAME')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')
NEO4J_DATABASE = os.getenv('NEO4J_DATABASE') or 'neo4j'
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
# Note the code below is unique to this course environment, and not a
# standard part of Neo4j's integration with OpenAI. Remove if running
# in your own environment.
#OPENAI_ENDPOINT = os.getenv('OPENAI_BASE_URL') + '/embeddings'

# Global constants
VECTOR_INDEX_NAME = 'abstract_chunks'
VECTOR_NODE_LABEL = 'Chunk'
VECTOR_SOURCE_PROPERTY = 'text'
VECTOR_EMBEDDING_PROPERTY = 'textEmbedding'

# %%
kg = Neo4jGraph(
    url=NEO4J_URI, username=NEO4J_USERNAME, password=NEO4J_PASSWORD, database=NEO4J_DATABASE
)

# %% [markdown]
# ### Query the abstracts of the documents

# %%
papers = kg.query("""
    MATCH (p:Paper)
    WHERE p.abstract IS NOT NULL AND p.abstract <> ''
    RETURN p.paperId as paperId, p.abstract as abstract, p.title as title
""")

# %%
len(papers)
# Out:
# 6867

# %%
papers[0]
# Out:
# {'paperId': '1e5cd344430d8de5bdb866ea5e8612467e69b689',
#  'abstract': '(1800). III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char. The Philosophical Magazine: Vol. 7, No. 25, pp. 35-46.',
#  'title': 'III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char'}

# %%
item1_text = papers[0]['title'] + ' ' + papers[0]['abstract']

# %%
item1_text[0:1500]
# Out:
# 'III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char (1800). III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char. The Philosophical Magazine: Vol. 7, No. 25, pp. 35-46.'

# %% [markdown]
# ### Split Form 10-K sections into chunks
# - Set up text splitter using LangChain
# - For now, split only the text from the "item 1" section

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 2000,
    chunk_overlap  = 200,
    length_function = len,
    is_separator_regex = False,
)

# %%
item1_text_chunks = text_splitter.split_text(item1_text)

# %%
type(item1_text_chunks)
# Out:
# list

# %%
len(item1_text_chunks)
# Out:
# 1

# %%
item1_text_chunks[0]
# Out:
# 'III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char (1800). III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char. The Philosophical Magazine: Vol. 7, No. 25, pp. 35-46.'

# %% [markdown]
# - Set up helper function to chunk all sections of the Form 10-K
# - You'll limit the number of chunks in each section to 20 to speed things up

# %%
def split_paper_abstract(paper: dict):
    chunks_with_metadata = [] # use this to accumlate chunk records
    for item in ['abstract']: # pull these keys from the json
        item_text = paper[item] # grab the text of the item
        item_text_chunks = text_splitter.split_text(item_text) # split the text into chunks
        chunk_seq_id = 0
        for chunk in item_text_chunks[:20]: # only take the first 20 chunks
            paper_id = paper['paperId']
            # finally, construct a record with metadata and the chunk text
            chunks_with_metadata.append({
                'text': chunk,
                # metadata from looping...
                'key': item,
                'chunkSeqId': chunk_seq_id,
                # constructed metadata...
                'paper_id': f'{paper_id}', # pulled from the filename
                'chunkId': f'{paper_id}-{item}-chunk{chunk_seq_id:04d}',
                # metadata from file...
                'title': paper['title'],
                'source': f'{paper_id}'
            })
            chunk_seq_id += 1
        print(f'\tSplit into {chunk_seq_id} chunks')
    return chunks_with_metadata

# %%
first_file_chunks = split_paper_abstract(papers[0])
# Out:
# 	Split into 1 chunks

# %%
first_file_chunks[0]
# Out:
# {'text': '(1800). III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char. The Philosophical Magazine: Vol. 7, No. 25, pp. 35-46.',
#  'key': 'abstract',
#  'chunkSeqId': 0,
#  'paper_id': '1e5cd344430d8de5bdb866ea5e8612467e69b689',
#  'chunkId': '1e5cd344430d8de5bdb866ea5e8612467e69b689-abstract-chunk0000',
#  'title': 'III. On the origin and progress of the manufacture of pig-iron with pit-coal; and comparison of the value and effects of pit-coal, wood, and peat-char',
#  'source': '1e5cd344430d8de5bdb866ea5e8612467e69b689'}

# %% [markdown]
# ### Create graph nodes using text chunks

# %%
merge_chunk_node_query = """
MERGE(mergedChunk:Chunk {chunkId: $chunkParam.chunkId})
    ON CREATE SET
        mergedChunk.title = $chunkParam.title,
        mergedChunk.chunkSeqId = $chunkParam.chunkSeqId,
        mergedChunk.text = $chunkParam.text,
        mergedChunk.source = $chunkParam.source
RETURN mergedChunk
"""

# %% [markdown]
# - Set up connection to graph instance using LangChain

# %% [markdown]
# - Create a single chunk node for now

# %%
kg.query(merge_chunk_node_query,
         params={'chunkParam':first_file_chunks[0]})
# Out:
# Processing paper 1e5cd344430d8de5bdb866ea5e8612467e69b689
# 	Split into 1 chunks
# 	Processing paper chunk 1e5cd344430d8de5bdb866ea5e8612467e69b689-abstract-chunk0000
# Processing paper c85acc8c6ac5eb7466e26517ae33aeac6fec6689
# 	Split into 1 chunks
# 	Processing paper chunk c85acc8c6ac5eb7466e26517ae33aeac6fec6689-abstract-chunk0000
# Processing paper bd5ae6e3dd85b54442c70701f6b19a35891423f0
# 	Split into 1 chunks
# 	Processing paper chunk bd5ae6e3dd85b54442c70701f6b19a35891423f0-abstract-chunk0000
# Processing paper eaeeb3c3d6726464ead8561082a7d72d8e7a0d64
# 	Split into 1 chunks
# 	Processing paper chunk eaeeb3c3d6726464ead8561082a7d72d8e7a0d64-abstract-chunk0000
# Processing paper 1432bfc59b9de4fd02554be99f181e2db4e10f37
# 	Split into 1 chunks
# 	Processing paper chunk 1432bfc59b9de4fd02554be99f181e2db4e10f37-abstract-chunk0000
# Processing paper 49ac1b055ed8da31193644c868b3173ed3e2a24f
# 	Split into 1 chunks
# 	Processing paper chunk 49ac1b055ed8da31193644c868b3173ed3e2a24f-abstract-chunk0000
# Processing paper 8658bf3b526cd2688f1ebaac1d2ab7a905444233
# 	Split into 1 chunks
# 	Processing paper chunk 8658bf3b526cd2688f1ebaac1d2ab7a905444233-abstract-chunk0000
# Processing paper d18f5997551c02196cd8d41b1f007191b4893013
# 	Split into 1 chunks
# 	Processing paper chunk d18f5997551c02196cd8d41b1f007191b4893013-abstract-chunk0000
# Processing paper 138cdc9ebc1583e4e6a7c7d5596570a620c95800
# 	Split into 1 chunks
# 	Processing paper chunk 138cdc9ebc1583e4e6a7c7d5596570a620c95800-abstract-chunk0000
# Processing paper 3bed780ecbd934b1bdf8320f278ffc6dd4e3f827
# 	Split into 1 chunks
# 	Processing paper chunk 3bed780ecbd934b1bdf8320f278ffc6dd4e3f827-abstract-chunk0000
# Processing paper 9d0bb088a57c274c84d08b7f4fe106140c18f35b
# 	Split into 2 chunks
# 	Processing paper chunk 9d0bb088a57c274c84d08b7f4fe106140c18f35b-abstract-chunk0000
# 	Processing paper chunk 9d0bb088a57c274c84d08b7f4fe106140c18f35b-abstract-chunk0001
# Processing paper b46b1952160ba7a5ecd7b05e4cedb9d0c8f6ec12
# 	Split into 1 chunks
# 	Processing paper chunk b46b1952160ba7a5ecd7b05e4cedb9d0c8f6ec12-abstract-chunk0000
# Processing paper 0edeae6f5f4abbc72608b2e722c025d283658181
# 	Split into 1 chunks
# 	Processing paper chunk 0edeae6f5f4abbc72608b2e722c025d283658181-abstract-chunk0000
# Processing paper 60c3b0a6e0769644c13db6a5cb9134a93efe22bb
# 	Split into 1 chunks
# 	Processing paper chunk 60c3b0a6e0769644c13db6a5cb9134a93efe22bb-abstract-chunk0000
# Processing paper c3ca195966c089642bb94f053c2ca135af068f8f
# 	Split into 1 chunks
# 	Processing paper chunk c3ca195966c089642bb94f053c2ca135af068f8f-abstract-chunk0000
# Processing paper c5104a148dfd34604ce2b58207a81ce0d46f6bc3
# 	Split into 1 chunks
# 	Processing paper chunk c5104a148dfd34604ce2b58207a81ce0d46f6bc3-abstract-chunk0000
# Processing paper 0ce4984341853d7a35815bc61b7d217bee3e9b93
# 	Split into 1 chunks
# 	Processing paper chunk 0ce4984341853d7a35815bc61b7d217bee3e9b93-abstract-chunk0000
# Processing paper 895ccbdd77ff7461f53c90b745ce70a58b0a9fa7
# 	Split into 1 chunks
# 	Processing paper chunk 895ccbdd77ff7461f53c90b745ce70a58b0a9fa7-abstract-chunk0000
# Processing paper 6f6f9b459a75932754b993a308acdd986e0cbdfa
# 	Split into 1 chunks
# 	Processing paper chunk 6f6f9b459a75932754b993a308acdd986e0cbdfa-abstract-chunk0000
# Processing paper c7a21aa3b201412e786b32badc812af30ddaae2f
# 	Split into 1 chunks
# 	Processing paper chunk c7a21aa3b201412e786b32badc812af30ddaae2f-abstract-chunk0000
# Processing paper f69db4835380537de40c4a3d536ef989c0bd9119
# 	Split into 1 chunks
# 	Processing paper chunk f69db4835380537de40c4a3d536ef989c0bd9119-abstract-chunk0000
# Processing paper 4d820d28ed91626ebb4078cb26f88d5c06dc4714
# 	Split into 1 chunks
# 	Processing paper chunk 4d820d28ed91626ebb4078cb26f88d5c06dc4714-abstract-chunk0000
# Processing paper 688c2ac32a7e6ee31942eee0f0f931a0e44dc84e
# 	Split into 1 chunks
# 	Processing paper chunk 688c2ac32a7e6ee31942eee0f0f931a0e44dc84e-abstract-chunk0000
# Processing paper 494054a886a67882546c551877d3d76966054870
# 	Split into 1 chunks
# 	Processing paper chunk 494054a886a67882546c551877d3d76966054870-abstract-chunk0000
# Processing paper 402ef3c2f82c199daae9d3d68bf1ccd54459115a
# 	Split into 1 chunks
# 	Processing paper chunk 402ef3c2f82c199daae9d3d68bf1ccd54459115a-abstract-chunk0000
# Processing paper 9438d1dd8a3c414d7d5c135ebbe60927826d8e5b
# 	Split into 1 chunks
# 	Processing paper chunk 9438d1dd8a3c414d7d5c135ebbe60927826d8e5b-abstract-chunk0000
# Processing paper e44b43c23bba16818a04fb74925d5b0548737377
# 	Split into 1 chunks
# 	Processing paper chunk e44b43c23bba16818a04fb74925d5b0548737377-abstract-chunk0000
# Processing paper 8a06f779d8dcb5114acfec9624cc8217575f355f
# 	Split into 1 chunks
# 	Processing paper chunk 8a06f779d8dcb5114acfec9624cc8217575f355f-abstract-chunk0000
# Processing paper 909aa833954a0d1df6dd1bf6856fdf0770e3f099
# 	Split into 1 chunks
# 	Processing paper chunk 909aa833954a0d1df6dd1bf6856fdf0770e3f099-abstract-chunk0000
# Processing paper 68d3c87d3420fa81ef71096fd07ec43710ed260b
# 	Split into 1 chunks
# 	Processing paper chunk 68d3c87d3420fa81ef71096fd07ec43710ed260b-abstract-chunk0000
# Processing paper 417e51e98cd4c9431dcb2fa536636bed065e34ad
# 	Split into 1 chunks
# 	Processing paper chunk 417e51e98cd4c9431dcb2fa536636bed065e34ad-abstract-chunk0000
# Processing paper 6bf683500e8e9efd92add4e167f8959b5b7ecb4f
# 	Split into 1 chunks
# 	Processing paper chunk 6bf683500e8e9efd92add4e167f8959b5b7ecb4f-abstract-chunk0000
# Processing paper 14227916796d504100ec20af8df0abe95df78afb
# 	Split into 1 chunks
# 	Processing paper chunk 14227916796d504100ec20af8df0abe95df78afb-abstract-chunk0000
# Processing paper bdf4e7d440f3f159e7209693fa20298fe9781ad1
# 	Split into 1 chunks
# 	Processing paper chunk bdf4e7d440f3f159e7209693fa20298fe9781ad1-abstract-chunk0000
# Processing paper 5b4add946a9373dbf8c279ea7ad848873c6a8b1a
# 	Split into 1 chunks
# 	Processing paper chunk 5b4add946a9373dbf8c279ea7ad848873c6a8b1a-abstract-chunk0000
# Processing paper 16f2eacb46b33ab6e9d65d6da74be84f7fb6bb88
# 	Split into 1 chunks
# 	Processing paper chunk 16f2eacb46b33ab6e9d65d6da74be84f7fb6bb88-abstract-chunk0000
# Processing paper 3206440e7b5861d7ad6cb2c4369f6c27103f4c76
# 	Split into 1 chunks
# 	Processing paper chunk 3206440e7b5861d7ad6cb2c4369f6c27103f4c76-abstract-chunk0000
# Processing paper 7b66f2e39ba0fb763969538cf224d23e9670a4fc
# 	Split into 2 chunks
# 	Processing paper chunk 7b66f2e39ba0fb763969538cf224d23e9670a4fc-abstract-chunk0000
# 	Processing paper chunk 7b66f2e39ba0fb763969538cf224d23e9670a4fc-abstract-chunk0001
# Processing paper f758bf13e1439fa1316f645d53cd89cc85b01404
# 	Split into 1 chunks
# 	Processing paper chunk f758bf13e1439fa1316f645d53cd89cc85b01404-abstract-chunk0000
# Processing paper b1a58e73360f2df57429a52d6ef98161c064887a
# 	Split into 1 chunks
# 	Processing paper chunk b1a58e73360f2df57429a52d6ef98161c064887a-abstract-chunk0000
# Processing paper 264315fd4f926968683dacec0fbfc5632e4c65d7
# 	Split into 1 chunks
# 	Processing paper chunk 264315fd4f926968683dacec0fbfc5632e4c65d7-abstract-chunk0000
# Processing paper 6fd4f44d283fce0dc14aa2fd0323d86ab750df36
# 	Split into 1 chunks
# 	Processing paper chunk 6fd4f44d283fce0dc14aa2fd0323d86ab750df36-abstract-chunk0000
# Processing paper e9e5deb482fc598a0cc89ec5b952ceb04fe172a3
# 	Split into 1 chunks
# 	Processing paper chunk e9e5deb482fc598a0cc89ec5b952ceb04fe172a3-abstract-chunk0000
# Processing paper 2dc393fe8a708f99cf5d872d61f026c56588844c
# 	Split into 1 chunks
# 	Processing paper chunk 2dc393fe8a708f99cf5d872d61f026c56588844c-abstract-chunk0000
# Processing paper ef40cd6587e8528a536f95c98a6ea6a96cab53a4
# 	Split into 1 chunks
# 	Processing paper chunk ef40cd6587e8528a536f95c98a6ea6a96cab53a4-abstract-chunk0000
# Processing paper c58d20ab97c3a06040e33034af08fcc2f5c9c35f
# 	Split into 1 chunks
# 	Processing paper chunk c58d20ab97c3a06040e33034af08fcc2f5c9c35f-abstract-chunk0000
# Processing paper e4f0c1331abfec2ca1f37ca569a78ea056676aae
# 	Split into 1 chunks
# 	Processing paper chunk e4f0c1331abfec2ca1f37ca569a78ea056676aae-abstract-chunk0000
# Processing paper 42b97316776c820340c81128fb9832188f10dbef
# 	Split into 1 chunks
# 	Processing paper chunk 42b97316776c820340c81128fb9832188f10dbef-abstract-chunk0000
# Processing paper d00e68e4a2f059e1e1197905a2b21f41aee201ac
# 	Split into 1 chunks
# 	Processing paper chunk d00e68e4a2f059e1e1197905a2b21f41aee201ac-abstract-chunk0000
# Processing paper e9d4e251337fabd1187482f706b3b8109203eb7d
# 	Split into 1 chunks
# 	Processing paper chunk e9d4e251337fabd1187482f706b3b8109203eb7d-abstract-chunk0000
# Processing paper 0748101ba2ae5511bb35cdc9c889f39115017f8a
# 	Split into 1 chunks
# 	Processing paper chunk 0748101ba2ae5511bb35cdc9c889f39115017f8a-abstract-chunk0000
# Processing paper 552f070fbcd943e688d40cf295adb80e1ec8a18b
# 	Split into 2 chunks
# 	Processing paper chunk 552f070fbcd943e688d40cf295adb80e1ec8a18b-abstract-chunk0000
# 	Processing paper chunk 552f070fbcd943e688d40cf295adb80e1ec8a18b-abstract-chunk0001
# Processing paper c04ca48ad26d70ede688994b2ecc32920de61752
# 	Split into 2 chunks
# 	Processing paper chunk c04ca48ad26d70ede688994b2ecc32920de61752-abstract-chunk0000
# 	Processing paper chunk c04ca48ad26d70ede688994b2ecc32920de61752-abstract-chunk0001
# Processing paper 18de50c46903ea51ded05c1e944797178bd04214
# 	Split into 1 chunks
# 	Processing paper chunk 18de50c46903ea51ded05c1e944797178bd04214-abstract-chunk0000
# Processing paper 6c81fb14c2bf4af42f1ccdb28b25a3c1efe77607
# 	Split into 2 chunks
# 	Processing paper chunk 6c81fb14c2bf4af42f1ccdb28b25a3c1efe77607-abstract-chunk0000
# 	Processing paper chunk 6c81fb14c2bf4af42f1ccdb28b25a3c1efe77607-abstract-chunk0001
# Processing paper cd22748274a3927d455f832e64c56d7c508d6f86
# 	Split into 1 chunks
# 	Processing paper chunk cd22748274a3927d455f832e64c56d7c508d6f86-abstract-chunk0000
# Processing paper bd974347fe39425bb83a5e1ae318d54b1ad60b07
# 	Split into 1 chunks
# 	Processing paper chunk bd974347fe39425bb83a5e1ae318d54b1ad60b07-abstract-chunk0000
# Processing paper 87d921ccfbfc933f89fdf2cec445e5004d7a7aa4
# 	Split into 1 chunks
# 	Processing paper chunk 87d921ccfbfc933f89fdf2cec445e5004d7a7aa4-abstract-chunk0000
# Processing paper 6382084de434ece986a5733037b7d9195dd9ecae
# 	Split into 1 chunks
# 	Processing paper chunk 6382084de434ece986a5733037b7d9195dd9ecae-abstract-chunk0000
# Processing paper ee0aa1181dcb6d6189f0c3927b678cfbd81c4b94
# 	Split into 1 chunks
# 	Processing paper chunk ee0aa1181dcb6d6189f0c3927b678cfbd81c4b94-abstract-chunk0000
# Processing paper fe9483fd4c28aa042e9682d01fd8bb35a67ec0a9
# 	Split into 1 chunks
# 	Processing paper chunk fe9483fd4c28aa042e9682d01fd8bb35a67ec0a9-abstract-chunk0000
# Processing paper 3b5668acf61908d47cbae22df0c1504f2a01d497
# 	Split into 1 chunks
# 	Processing paper chunk 3b5668acf61908d47cbae22df0c1504f2a01d497-abstract-chunk0000
# Processing paper 836ef53b85b2e650b3b4d54caf96fe2d3ed97161
# 	Split into 1 chunks
# 	Processing paper chunk 836ef53b85b2e650b3b4d54caf96fe2d3ed97161-abstract-chunk0000
# Processing paper 461983d1765968582e083d3947c655dfa2f27e91
# 	Split into 2 chunks
# 	Processing paper chunk 461983d1765968582e083d3947c655dfa2f27e91-abstract-chunk0000
# 	Processing paper chunk 461983d1765968582e083d3947c655dfa2f27e91-abstract-chunk0001
# Processing paper 3b6f2e36382eb067c979a1d85d860a65b871bfa6
# 	Split into 1 chunks
# 	Processing paper chunk 3b6f2e36382eb067c979a1d85d860a65b871bfa6-abstract-chunk0000
# Processing paper ca52609c27feac84dc581058013dc8bbb06c8411
# 	Split into 1 chunks
# 	Processing paper chunk ca52609c27feac84dc581058013dc8bbb06c8411-abstract-chunk0000
# Processing paper 57219e8e0f479f0f7ef61c33aae0c1fe7326153b
# 	Split into 2 chunks
# 	Processing paper chunk 57219e8e0f479f0f7ef61c33aae0c1fe7326153b-abstract-chunk0000
# 	Processing paper chunk 57219e8e0f479f0f7ef61c33aae0c1fe7326153b-abstract-chunk0001
# Processing paper 74b6330b0e0f24d7bca84ff178835aa21d760770
# 	Split into 1 chunks
# 	Processing paper chunk 74b6330b0e0f24d7bca84ff178835aa21d760770-abstract-chunk0000
# Processing paper bb04b7d3fe8a340aa4c333550b1659162f355c29
# 	Split into 2 chunks
# 	Processing paper chunk bb04b7d3fe8a340aa4c333550b1659162f355c29-abstract-chunk0000
# 	Processing paper chunk bb04b7d3fe8a340aa4c333550b1659162f355c29-abstract-chunk0001
# Processing paper 10869423891a9249d23eec9b55f89a02e0580b16
# 	Split into 1 chunks
# 	Processing paper chunk 10869423891a9249d23eec9b55f89a02e0580b16-abstract-chunk0000
# Processing paper 459a4362980327424f6b317230911274cf009a46
# 	Split into 2 chunks
# 	Processing paper chunk 459a4362980327424f6b317230911274cf009a46-abstract-chunk0000
# 	Processing paper chunk 459a4362980327424f6b317230911274cf009a46-abstract-chunk0001
# Processing paper 63aed5135bf873a071ecae0a44d1eb666a18de80
# 	Split into 1 chunks
# 	Processing paper chunk 63aed5135bf873a071ecae0a44d1eb666a18de80-abstract-chunk0000
# Processing paper 80304266f19512f7765045337600f897b60b5533
# 	Split into 1 chunks
# 	Processing paper chunk 80304266f19512f7765045337600f897b60b5533-abstract-chunk0000
# Processing paper 8fa72f04358eab415af993fffaecd903eafd8a58
# 	Split into 1 chunks
# 	Processing paper chunk 8fa72f04358eab415af993fffaecd903eafd8a58-abstract-chunk0000
# Processing paper cccd136bb629869abd07815f6ba53bbf3725a63f
# 	Split into 1 chunks
# 	Processing paper chunk cccd136bb629869abd07815f6ba53bbf3725a63f-abstract-chunk0000
# Processing paper 015c446ac0e884330aa08a971c280b30352fcd87
# 	Split into 1 chunks
# 	Processing paper chunk 015c446ac0e884330aa08a971c280b30352fcd87-abstract-chunk0000
# Processing paper 2274f4f4604d25d7ad9a6eb222ac6573da7f11d7
# 	Split into 1 chunks
# 	Processing paper chunk 2274f4f4604d25d7ad9a6eb222ac6573da7f11d7-abstract-chunk0000
# Processing paper 2f509202b5006d75a50efec01a8dcac19efb3af6
# 	Split into 1 chunks
# 	Processing paper chunk 2f509202b5006d75a50efec01a8dcac19efb3af6-abstract-chunk0000
# Processing paper 6e05c0ffefc15455e928c28e764b4c87c32af184
# 	Split into 4 chunks
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0000
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0001
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0002
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0003
# Processing paper 89fe30e830401a6432dfc790a74905b8e94f17f6
# 	Split into 1 chunks
# 	Processing paper chunk 89fe30e830401a6432dfc790a74905b8e94f17f6-abstract-chunk0000
# Processing paper 0659fc02b2366617e9db8a53a1f1c901b5dc9a1f
# 	Split into 1 chunks
# 	Processing paper chunk 0659fc02b2366617e9db8a53a1f1c901b5dc9a1f-abstract-chunk0000
# Processing paper 416dd47105305512399eb7742af78570c750eb23
# 	Split into 1 chunks
# 	Processing paper chunk 416dd47105305512399eb7742af78570c750eb23-abstract-chunk0000
# Processing paper 4c7b7b2788fa4ca992f2314f03538c34e610342d
# 	Split into 1 chunks
# 	Processing paper chunk 4c7b7b2788fa4ca992f2314f03538c34e610342d-abstract-chunk0000
# Processing paper 55efb189bc0644c187eab3ddcd55bb3fd9207048
# 	Split into 1 chunks
# 	Processing paper chunk 55efb189bc0644c187eab3ddcd55bb3fd9207048-abstract-chunk0000
# Processing paper 978e744fe77709b8efef6808b94f1231484a7062
# 	Split into 1 chunks
# 	Processing paper chunk 978e744fe77709b8efef6808b94f1231484a7062-abstract-chunk0000
# Processing paper d056025641750fe1fed25d5de87a4f565e53acca
# 	Split into 1 chunks
# 	Processing paper chunk d056025641750fe1fed25d5de87a4f565e53acca-abstract-chunk0000
# Processing paper d7ac5161a3b19098da3c2891e72a2dcb9cb8373c
# 	Split into 1 chunks
# 	Processing paper chunk d7ac5161a3b19098da3c2891e72a2dcb9cb8373c-abstract-chunk0000
# Processing paper 1804e9e32dd4eb76a32e2ba96c7899a569869236
# 	Split into 1 chunks
# 	Processing paper chunk 1804e9e32dd4eb76a32e2ba96c7899a569869236-abstract-chunk0000
# Processing paper 5cf3f12a5750e821f2f53fecbb0e6dbae01ea5f5
# 	Split into 1 chunks
# 	Processing paper chunk 5cf3f12a5750e821f2f53fecbb0e6dbae01ea5f5-abstract-chunk0000
# Processing paper ba51eaafa9d13788566c08786cd4545bf138bc56
# 	Split into 1 chunks
# 	Processing paper chunk ba51eaafa9d13788566c08786cd4545bf138bc56-abstract-chunk0000
# Processing paper be08f8846b625e5cce70d9b8df6c092d2d37e789
# 	Split into 2 chunks
# 	Processing paper chunk be08f8846b625e5cce70d9b8df6c092d2d37e789-abstract-chunk0000
# 	Processing paper chunk be08f8846b625e5cce70d9b8df6c092d2d37e789-abstract-chunk0001
# Processing paper f37bd611a0fccf1288350529b673a84a4832cd83
# 	Split into 1 chunks
# 	Processing paper chunk f37bd611a0fccf1288350529b673a84a4832cd83-abstract-chunk0000
# Processing paper 00aa3398b80b1611c825523e578028cff32d765f
# 	Split into 1 chunks
# 	Processing paper chunk 00aa3398b80b1611c825523e578028cff32d765f-abstract-chunk0000
# Processing paper 05b090ecac784673c37ea9cd890d1eaa46354095
# 	Split into 1 chunks
# 	Processing paper chunk 05b090ecac784673c37ea9cd890d1eaa46354095-abstract-chunk0000
# Processing paper 7e440765d8971816c7f3cb88a3f74774cea452b0
# 	Split into 1 chunks
# 	Processing paper chunk 7e440765d8971816c7f3cb88a3f74774cea452b0-abstract-chunk0000
# Processing paper 917e25aa1d063b415c890b7d8d49d270e2efef1b
# 	Split into 1 chunks
# 	Processing paper chunk 917e25aa1d063b415c890b7d8d49d270e2efef1b-abstract-chunk0000
# Processing paper 99c2a83f130d0630ebd1f9a66e690dfaac9b49a3
# 	Split into 1 chunks
# 	Processing paper chunk 99c2a83f130d0630ebd1f9a66e690dfaac9b49a3-abstract-chunk0000
# Processing paper fc52fb6998be08bbf197708b6aa7dd2c183d5bc1
# 	Split into 1 chunks
# 	Processing paper chunk fc52fb6998be08bbf197708b6aa7dd2c183d5bc1-abstract-chunk0000
# Processing paper 0c9fc58a2236d4540fb523c8e9470744594ce8ba
# 	Split into 1 chunks
# 	Processing paper chunk 0c9fc58a2236d4540fb523c8e9470744594ce8ba-abstract-chunk0000
# Processing paper 1fda875a07ef976b2c1b212c63de99fb3a36fe80
# 	Split into 1 chunks
# 	Processing paper chunk 1fda875a07ef976b2c1b212c63de99fb3a36fe80-abstract-chunk0000
# Processing paper 417b6fdc34fa853ea474a88ee81a27df8a1ddb6b
# 	Split into 1 chunks
# 	Processing paper chunk 417b6fdc34fa853ea474a88ee81a27df8a1ddb6b-abstract-chunk0000
# Processing paper 19de1eed6795cd7c65803df79c2279ade1bf403b
# 	Split into 1 chunks
# 	Processing paper chunk 19de1eed6795cd7c65803df79c2279ade1bf403b-abstract-chunk0000
# Processing paper 57ec18cb08c8d9da143d0939dbfed87bcb22a4d2
# 	Split into 1 chunks
# 	Processing paper chunk 57ec18cb08c8d9da143d0939dbfed87bcb22a4d2-abstract-chunk0000
# Processing paper b2f3ae50b598514e1a892256a689feb8b699d9c7
# 	Split into 1 chunks
# 	Processing paper chunk b2f3ae50b598514e1a892256a689feb8b699d9c7-abstract-chunk0000
# Processing paper d4827844a66bc05d103de604ec535b1df5dfe17d
# 	Split into 1 chunks
# 	Processing paper chunk d4827844a66bc05d103de604ec535b1df5dfe17d-abstract-chunk0000
# Processing paper d7d2096c52cb3d0e1ce6c4b749fe0bc1ddef4953
# 	Split into 1 chunks
# 	Processing paper chunk d7d2096c52cb3d0e1ce6c4b749fe0bc1ddef4953-abstract-chunk0000
# Processing paper db27d94baae6809abaea58ff39efb79f08477df6
# 	Split into 1 chunks
# 	Processing paper chunk db27d94baae6809abaea58ff39efb79f08477df6-abstract-chunk0000
# Processing paper e47a24e897419acbf49907958ef47e573e804a02
# 	Split into 1 chunks
# 	Processing paper chunk e47a24e897419acbf49907958ef47e573e804a02-abstract-chunk0000
# Processing paper 314cc25cd5aa73cd71ff5e8165015366cbe52310
# 	Split into 2 chunks
# 	Processing paper chunk 314cc25cd5aa73cd71ff5e8165015366cbe52310-abstract-chunk0000
# 	Processing paper chunk 314cc25cd5aa73cd71ff5e8165015366cbe52310-abstract-chunk0001
# Processing paper 936da812e62f14151ec5980c0650dd677de28a8a
# 	Split into 1 chunks
# 	Processing paper chunk 936da812e62f14151ec5980c0650dd677de28a8a-abstract-chunk0000
# Processing paper b73fb06516e3d9026c48c5b458cb9c5ee9a48335
# 	Split into 1 chunks
# 	Processing paper chunk b73fb06516e3d9026c48c5b458cb9c5ee9a48335-abstract-chunk0000
# Processing paper 388cbca4fa7db0b926a95463f42825f3d5c83845
# 	Split into 1 chunks
# 	Processing paper chunk 388cbca4fa7db0b926a95463f42825f3d5c83845-abstract-chunk0000
# Processing paper 6099fa73b93f0ad1782e8d698c82c08340ba9975
# 	Split into 1 chunks
# 	Processing paper chunk 6099fa73b93f0ad1782e8d698c82c08340ba9975-abstract-chunk0000
# Processing paper b3c6afd425c12ed11fb8995f83d146fc6a5c3d05
# 	Split into 1 chunks
# 	Processing paper chunk b3c6afd425c12ed11fb8995f83d146fc6a5c3d05-abstract-chunk0000
# Processing paper 029d5712d72c4db1c92465aee76a23172cdd43d6
# 	Split into 1 chunks
# 	Processing paper chunk 029d5712d72c4db1c92465aee76a23172cdd43d6-abstract-chunk0000
# Processing paper 322597d75dc8b89bf09dd6cf2614f08f12dadb35
# 	Split into 1 chunks
# 	Processing paper chunk 322597d75dc8b89bf09dd6cf2614f08f12dadb35-abstract-chunk0000
# Processing paper 3d87776824a87007a16644e1c6970768d9fcfd73
# 	Split into 1 chunks
# 	Processing paper chunk 3d87776824a87007a16644e1c6970768d9fcfd73-abstract-chunk0000
# Processing paper 48e191de1cdd03f07854c29f9963ad2515e60a6a
# 	Split into 1 chunks
# 	Processing paper chunk 48e191de1cdd03f07854c29f9963ad2515e60a6a-abstract-chunk0000
# Processing paper 8aeeedae90d5ce75ee5c51f815fb9305e25d37ba
# 	Split into 1 chunks
# 	Processing paper chunk 8aeeedae90d5ce75ee5c51f815fb9305e25d37ba-abstract-chunk0000
# Processing paper 9bf809b7727c0e9f80021657049edae4a8e71e84
# 	Split into 1 chunks
# 	Processing paper chunk 9bf809b7727c0e9f80021657049edae4a8e71e84-abstract-chunk0000
# Processing paper b6235fb2df343b4b3b3bbf443ccc1b62210f9967
# 	Split into 1 chunks
# 	Processing paper chunk b6235fb2df343b4b3b3bbf443ccc1b62210f9967-abstract-chunk0000
# Processing paper ffe9f6f08165fa0add71d599ea30c6a4291f7eb3
# 	Split into 1 chunks
# 	Processing paper chunk ffe9f6f08165fa0add71d599ea30c6a4291f7eb3-abstract-chunk0000
# Processing paper 0283f01f612ab4e403691765db2da6b2cd729a4d
# 	Split into 1 chunks
# 	Processing paper chunk 0283f01f612ab4e403691765db2da6b2cd729a4d-abstract-chunk0000
# Processing paper 10687584677c3bcfb0cfaadf240c9eff3257ba96
# 	Split into 1 chunks
# 	Processing paper chunk 10687584677c3bcfb0cfaadf240c9eff3257ba96-abstract-chunk0000
# Processing paper 9f482f1f5c604095a4730d05cc99f291fe8ee946
# 	Split into 1 chunks
# 	Processing paper chunk 9f482f1f5c604095a4730d05cc99f291fe8ee946-abstract-chunk0000
# Processing paper a8390849e288da56836fd6c002c3055ef5673f5b
# 	Split into 2 chunks
# 	Processing paper chunk a8390849e288da56836fd6c002c3055ef5673f5b-abstract-chunk0000
# 	Processing paper chunk a8390849e288da56836fd6c002c3055ef5673f5b-abstract-chunk0001
# Processing paper f7b3a2cd1de40e6c7798b8b6cbf430641e0a9287
# 	Split into 1 chunks
# 	Processing paper chunk f7b3a2cd1de40e6c7798b8b6cbf430641e0a9287-abstract-chunk0000
# Processing paper 3bd1f794875ea11b90f2d7f5faccf1b9e37828d0
# 	Split into 1 chunks
# 	Processing paper chunk 3bd1f794875ea11b90f2d7f5faccf1b9e37828d0-abstract-chunk0000
# Processing paper 41159220bf4ef527f8d5ac9935fbaa8f2bc30d95
# 	Split into 2 chunks
# 	Processing paper chunk 41159220bf4ef527f8d5ac9935fbaa8f2bc30d95-abstract-chunk0000
# 	Processing paper chunk 41159220bf4ef527f8d5ac9935fbaa8f2bc30d95-abstract-chunk0001
# Processing paper 6dc7aa3ea4b4c57da2a6a66454b6ab18a2fe3d37
# 	Split into 1 chunks
# 	Processing paper chunk 6dc7aa3ea4b4c57da2a6a66454b6ab18a2fe3d37-abstract-chunk0000
# Processing paper 659ab3d3030939e2d3b248b2db8bcc626192ac7a
# 	Split into 1 chunks
# 	Processing paper chunk 659ab3d3030939e2d3b248b2db8bcc626192ac7a-abstract-chunk0000
# Processing paper 7663998b03ef7e3ebd864fe5035564cdfd834bf2
# 	Split into 1 chunks
# 	Processing paper chunk 7663998b03ef7e3ebd864fe5035564cdfd834bf2-abstract-chunk0000
# Processing paper 24bc16fa1e97a35e9ea58c1c1456d20e84276079
# 	Split into 1 chunks
# 	Processing paper chunk 24bc16fa1e97a35e9ea58c1c1456d20e84276079-abstract-chunk0000
# Processing paper 8030bf667987ff5d9dd169067b0fec851d1f3b8f
# 	Split into 1 chunks
# 	Processing paper chunk 8030bf667987ff5d9dd169067b0fec851d1f3b8f-abstract-chunk0000
# Processing paper 9bd005e0a0494ca0a67ede02fd7e0ecb71681b90
# 	Split into 1 chunks
# 	Processing paper chunk 9bd005e0a0494ca0a67ede02fd7e0ecb71681b90-abstract-chunk0000
# Processing paper ad4a47be28f43a5dd52a30d4c4e6f4acce3ad9ce
# 	Split into 1 chunks
# 	Processing paper chunk ad4a47be28f43a5dd52a30d4c4e6f4acce3ad9ce-abstract-chunk0000
# Processing paper d0b1a8f061a7af536fb33dab3720a52ecf70a0c5
# 	Split into 1 chunks
# 	Processing paper chunk d0b1a8f061a7af536fb33dab3720a52ecf70a0c5-abstract-chunk0000
# Processing paper f05b35a00d779a9dbfdda8ad4a7efd8bc61f547f
# 	Split into 1 chunks
# 	Processing paper chunk f05b35a00d779a9dbfdda8ad4a7efd8bc61f547f-abstract-chunk0000
# Processing paper 261dbbef697eb434df811f3bb177710753a44870
# 	Split into 1 chunks
# 	Processing paper chunk 261dbbef697eb434df811f3bb177710753a44870-abstract-chunk0000
# Processing paper 8ed593a15492060d64fd7344745d84916bfb4875
# 	Split into 1 chunks
# 	Processing paper chunk 8ed593a15492060d64fd7344745d84916bfb4875-abstract-chunk0000
# Processing paper 9314a908d0fee5f12c9bc46850429d9eefb2dfc0
# 	Split into 1 chunks
# 	Processing paper chunk 9314a908d0fee5f12c9bc46850429d9eefb2dfc0-abstract-chunk0000
# Processing paper a4fd2b6f1c96f4ec19461d473f0435aeea6f4716
# 	Split into 1 chunks
# 	Processing paper chunk a4fd2b6f1c96f4ec19461d473f0435aeea6f4716-abstract-chunk0000
# Processing paper cd79fb9c1d3c6321e76bfb876e47506cd95b1af6
# 	Split into 2 chunks
# 	Processing paper chunk cd79fb9c1d3c6321e76bfb876e47506cd95b1af6-abstract-chunk0000
# 	Processing paper chunk cd79fb9c1d3c6321e76bfb876e47506cd95b1af6-abstract-chunk0001
# Processing paper d0d4929b9f23e3e1faf0786bad6c3baf7be82b69
# 	Split into 1 chunks
# 	Processing paper chunk d0d4929b9f23e3e1faf0786bad6c3baf7be82b69-abstract-chunk0000
# Processing paper 02fe361570c60dc29414e6019f6942a5135813e3
# 	Split into 1 chunks
# 	Processing paper chunk 02fe361570c60dc29414e6019f6942a5135813e3-abstract-chunk0000
# Processing paper 241c857d0258cc213e35d6ac4fa2fdf1e941ef39
# 	Split into 1 chunks
# 	Processing paper chunk 241c857d0258cc213e35d6ac4fa2fdf1e941ef39-abstract-chunk0000
# Processing paper 4a90d90405f92268529bdde512c538d2c7f175cb
# 	Split into 2 chunks
# 	Processing paper chunk 4a90d90405f92268529bdde512c538d2c7f175cb-abstract-chunk0000
# 	Processing paper chunk 4a90d90405f92268529bdde512c538d2c7f175cb-abstract-chunk0001
# Processing paper 7f7d8adbaeca1903181dbcceb453b7c4155cb0ed
# 	Split into 1 chunks
# 	Processing paper chunk 7f7d8adbaeca1903181dbcceb453b7c4155cb0ed-abstract-chunk0000
# Processing paper 8b721421d4a8e63bb060ea99f73534a0feba506e
# 	Split into 2 chunks
# 	Processing paper chunk 8b721421d4a8e63bb060ea99f73534a0feba506e-abstract-chunk0000
# 	Processing paper chunk 8b721421d4a8e63bb060ea99f73534a0feba506e-abstract-chunk0001
# Processing paper a082b150d6cf0b2596c260a5fc9408d8ccfb7be4
# 	Split into 1 chunks
# 	Processing paper chunk a082b150d6cf0b2596c260a5fc9408d8ccfb7be4-abstract-chunk0000
# Processing paper d6ba86db03a31e753c744fcaa6d895d7919d8d56
# 	Split into 2 chunks
# 	Processing paper chunk d6ba86db03a31e753c744fcaa6d895d7919d8d56-abstract-chunk0000
# 	Processing paper chunk d6ba86db03a31e753c744fcaa6d895d7919d8d56-abstract-chunk0001
# Processing paper e2eefd77d69f3fb7da82cabf76ce43f64fe53db6
# 	Split into 1 chunks
# 	Processing paper chunk e2eefd77d69f3fb7da82cabf76ce43f64fe53db6-abstract-chunk0000
# Processing paper 1a85002c52c31f50c7c2a950d307546dc1f8f111
# 	Split into 1 chunks
# 	Processing paper chunk 1a85002c52c31f50c7c2a950d307546dc1f8f111-abstract-chunk0000
# Processing paper 2de9cb3e31780104cae60471759596294bc8ba2a
# 	Split into 1 chunks
# 	Processing paper chunk 2de9cb3e31780104cae60471759596294bc8ba2a-abstract-chunk0000
# Processing paper 9a700d42161ae4b8acfdde297645b1d93986c56b
# 	Split into 1 chunks
# 	Processing paper chunk 9a700d42161ae4b8acfdde297645b1d93986c56b-abstract-chunk0000
# Processing paper a1f573febb87c9288a087445536d55cf5a106b0d
# 	Split into 1 chunks
# 	Processing paper chunk a1f573febb87c9288a087445536d55cf5a106b0d-abstract-chunk0000
# Processing paper a79a6da7579348cd5b4ed230d9ef3367c1d3f2e0
# 	Split into 2 chunks
# 	Processing paper chunk a79a6da7579348cd5b4ed230d9ef3367c1d3f2e0-abstract-chunk0000
# 	Processing paper chunk a79a6da7579348cd5b4ed230d9ef3367c1d3f2e0-abstract-chunk0001
# Processing paper ae566412f2eef35010605079e734a208e6c72264
# 	Split into 1 chunks
# 	Processing paper chunk ae566412f2eef35010605079e734a208e6c72264-abstract-chunk0000
# Processing paper b415ce9d80ff474b6a88f0b8fae2edd6b326d793
# 	Split into 1 chunks
# 	Processing paper chunk b415ce9d80ff474b6a88f0b8fae2edd6b326d793-abstract-chunk0000
# Processing paper b9a77adb11e2deb9790e3ea144b9ea55579f8cea
# 	Split into 1 chunks
# 	Processing paper chunk b9a77adb11e2deb9790e3ea144b9ea55579f8cea-abstract-chunk0000
# Processing paper ead83466deb581f75fe61733d6632bd3bdace899
# 	Split into 2 chunks
# 	Processing paper chunk ead83466deb581f75fe61733d6632bd3bdace899-abstract-chunk0000
# 	Processing paper chunk ead83466deb581f75fe61733d6632bd3bdace899-abstract-chunk0001
# Processing paper 1e29029b56defd31810986419272de563b88b507
# 	Split into 1 chunks
# 	Processing paper chunk 1e29029b56defd31810986419272de563b88b507-abstract-chunk0000
# Processing paper 2a901cfdc333c5804b74710f6b72b4483f1a84e7
# 	Split into 1 chunks
# 	Processing paper chunk 2a901cfdc333c5804b74710f6b72b4483f1a84e7-abstract-chunk0000
# Processing paper 3c7351fae8f4ab424612135cb23f4c87aafa1c43
# 	Split into 1 chunks
# 	Processing paper chunk 3c7351fae8f4ab424612135cb23f4c87aafa1c43-abstract-chunk0000
# Processing paper 64130afacdd708da5e1a9241836154a82c17ee1c
# 	Split into 1 chunks
# 	Processing paper chunk 64130afacdd708da5e1a9241836154a82c17ee1c-abstract-chunk0000
# Processing paper c3165d9635d0303607a1e49faa953f2ae8a42cc5
# 	Split into 1 chunks
# 	Processing paper chunk c3165d9635d0303607a1e49faa953f2ae8a42cc5-abstract-chunk0000
# Processing paper f41a85f621f6b35a86161d2171627affc0779f45
# 	Split into 2 chunks
# 	Processing paper chunk f41a85f621f6b35a86161d2171627affc0779f45-abstract-chunk0000
# 	Processing paper chunk f41a85f621f6b35a86161d2171627affc0779f45-abstract-chunk0001
# Processing paper 32e6ef0bc4c57df54536224889a942386b346d64
# 	Split into 1 chunks
# 	Processing paper chunk 32e6ef0bc4c57df54536224889a942386b346d64-abstract-chunk0000
# Processing paper 443d7d56ffba5bff5d9730215bcd3526d78844c0
# 	Split into 1 chunks
# 	Processing paper chunk 443d7d56ffba5bff5d9730215bcd3526d78844c0-abstract-chunk0000
# Processing paper f20bb44802b39fdfef9976d200eb79b363dba4bc
# 	Split into 1 chunks
# 	Processing paper chunk f20bb44802b39fdfef9976d200eb79b363dba4bc-abstract-chunk0000
# Processing paper 09f332f86e2f7221dfa0c8dbcebe41ce9e6b29bb
# 	Split into 1 chunks
# 	Processing paper chunk 09f332f86e2f7221dfa0c8dbcebe41ce9e6b29bb-abstract-chunk0000
# Processing paper 67fd95777e848c38b70b0347b647f337955578b6
# 	Split into 1 chunks
# 	Processing paper chunk 67fd95777e848c38b70b0347b647f337955578b6-abstract-chunk0000
# Processing paper c79b04c6cb12404a67c43acef7b92722c5d24de0
# 	Split into 1 chunks
# 	Processing paper chunk c79b04c6cb12404a67c43acef7b92722c5d24de0-abstract-chunk0000
# Processing paper ea8e2971c8ac7f416b669c0945d71092e518cf48
# 	Split into 1 chunks
# 	Processing paper chunk ea8e2971c8ac7f416b669c0945d71092e518cf48-abstract-chunk0000
# Processing paper f862ff755bbfc786f3a98a5bbce17f8caba2712d
# 	Split into 1 chunks
# 	Processing paper chunk f862ff755bbfc786f3a98a5bbce17f8caba2712d-abstract-chunk0000
# Processing paper f9e552681947a80967727b7a71c4d6d2cfec9af7
# 	Split into 1 chunks
# 	Processing paper chunk f9e552681947a80967727b7a71c4d6d2cfec9af7-abstract-chunk0000
# Processing paper 26e748f4d942288a5fba2817ca5ed1850d10d146
# 	Split into 1 chunks
# 	Processing paper chunk 26e748f4d942288a5fba2817ca5ed1850d10d146-abstract-chunk0000
# Processing paper 3a6104a381976e24b0752ca65e87a17ff06cd589
# 	Split into 1 chunks
# 	Processing paper chunk 3a6104a381976e24b0752ca65e87a17ff06cd589-abstract-chunk0000
# Processing paper 3f95399640a364cb0289f8c4d00915701a41a2b4
# 	Split into 1 chunks
# 	Processing paper chunk 3f95399640a364cb0289f8c4d00915701a41a2b4-abstract-chunk0000
# Processing paper f0b370fed5c25d97dc1b02a38e457cdd1f5b5da0
# 	Split into 1 chunks
# 	Processing paper chunk f0b370fed5c25d97dc1b02a38e457cdd1f5b5da0-abstract-chunk0000
# Processing paper 255af007e2b36096ade73e9069b2c95fd81f5412
# 	Split into 1 chunks
# 	Processing paper chunk 255af007e2b36096ade73e9069b2c95fd81f5412-abstract-chunk0000
# Processing paper 7006dbf612103c9c34c32adb9875aac866705df4
# 	Split into 1 chunks
# 	Processing paper chunk 7006dbf612103c9c34c32adb9875aac866705df4-abstract-chunk0000
# Processing paper 9a5bfd4ebad6d04df5bc33a8db33b5187242ef24
# 	Split into 1 chunks
# 	Processing paper chunk 9a5bfd4ebad6d04df5bc33a8db33b5187242ef24-abstract-chunk0000
# Processing paper a97b1359d2b453a9179dadb4cb9a81d5e0948b9b
# 	Split into 1 chunks
# 	Processing paper chunk a97b1359d2b453a9179dadb4cb9a81d5e0948b9b-abstract-chunk0000
# Processing paper 13dbc08bb81638f51e1f14f8d6cb2f791fc762f1
# 	Split into 1 chunks
# 	Processing paper chunk 13dbc08bb81638f51e1f14f8d6cb2f791fc762f1-abstract-chunk0000
# Processing paper 0ffbee27d652a4e4e1b3c757b8c06bb831baad6c
# 	Split into 1 chunks
# 	Processing paper chunk 0ffbee27d652a4e4e1b3c757b8c06bb831baad6c-abstract-chunk0000
# Processing paper 0d040a65ee44007cf77f2df69a1c3b0a27f54efa
# 	Split into 1 chunks
# 	Processing paper chunk 0d040a65ee44007cf77f2df69a1c3b0a27f54efa-abstract-chunk0000
# Processing paper 13bc9e5ab967709599219765dcda72faf2275a0e
# 	Split into 1 chunks
# 	Processing paper chunk 13bc9e5ab967709599219765dcda72faf2275a0e-abstract-chunk0000
# Processing paper 116090284de01bee8a801228ebc391e52cf95229
# 	Split into 1 chunks
# 	Processing paper chunk 116090284de01bee8a801228ebc391e52cf95229-abstract-chunk0000
# Processing paper 1c7d0994f55705facb1cd46ef14bb54ce692ca54
# 	Split into 1 chunks
# 	Processing paper chunk 1c7d0994f55705facb1cd46ef14bb54ce692ca54-abstract-chunk0000
# Processing paper 1d7808b3f1247083fd1c8f5fc4a02f656ecf2e33
# 	Split into 1 chunks
# 	Processing paper chunk 1d7808b3f1247083fd1c8f5fc4a02f656ecf2e33-abstract-chunk0000
# Processing paper 1e3d8cdd49539d09c8a565da7c68a412f33cbafc
# 	Split into 1 chunks
# 	Processing paper chunk 1e3d8cdd49539d09c8a565da7c68a412f33cbafc-abstract-chunk0000
# Processing paper 24af85e5e3732e54c0bc83338bfa9d84a71418a9
# 	Split into 1 chunks
# 	Processing paper chunk 24af85e5e3732e54c0bc83338bfa9d84a71418a9-abstract-chunk0000
# Processing paper 2f1ec3f641f23ed34e0ae350cb422ac27e8fd933
# 	Split into 1 chunks
# 	Processing paper chunk 2f1ec3f641f23ed34e0ae350cb422ac27e8fd933-abstract-chunk0000
# Processing paper 342755fa45061b0d1e85910cdff7292b9f939501
# 	Split into 1 chunks
# 	Processing paper chunk 342755fa45061b0d1e85910cdff7292b9f939501-abstract-chunk0000
# Processing paper 34ba1abcca832f0424bbbcb91b5e2645637a43bf
# 	Split into 1 chunks
# 	Processing paper chunk 34ba1abcca832f0424bbbcb91b5e2645637a43bf-abstract-chunk0000
# Processing paper 46916efab0489a6958d5c21a551d3c47676f5bbf
# 	Split into 1 chunks
# 	Processing paper chunk 46916efab0489a6958d5c21a551d3c47676f5bbf-abstract-chunk0000
# Processing paper 5292596f74d263ee2dce2c933beda1c6f77dedbe
# 	Split into 1 chunks
# 	Processing paper chunk 5292596f74d263ee2dce2c933beda1c6f77dedbe-abstract-chunk0000
# Processing paper 8692048a10a4c76c1e75008e56a65e7671f078c3
# 	Split into 1 chunks
# 	Processing paper chunk 8692048a10a4c76c1e75008e56a65e7671f078c3-abstract-chunk0000
# Processing paper 91a7411bff96b110c3084836304acd15002f9481
# 	Split into 1 chunks
# 	Processing paper chunk 91a7411bff96b110c3084836304acd15002f9481-abstract-chunk0000
# Processing paper 9a0d46a442087a91f6d6db1da2f7d30652ed953e
# 	Split into 1 chunks
# 	Processing paper chunk 9a0d46a442087a91f6d6db1da2f7d30652ed953e-abstract-chunk0000
# Processing paper 9d1364c6e8b30f80735fc79156200833725f337c
# 	Split into 1 chunks
# 	Processing paper chunk 9d1364c6e8b30f80735fc79156200833725f337c-abstract-chunk0000
# Processing paper a9a0c7dcd19d9ce06f3c2a89a83a0b29c0d8f537
# 	Split into 1 chunks
# 	Processing paper chunk a9a0c7dcd19d9ce06f3c2a89a83a0b29c0d8f537-abstract-chunk0000
# Processing paper acdeb62749efe973512a8cee91750e14969126e3
# 	Split into 1 chunks
# 	Processing paper chunk acdeb62749efe973512a8cee91750e14969126e3-abstract-chunk0000
# Processing paper c20e8b3a9734f639c4e5aee42319e97331339e2b
# 	Split into 1 chunks
# 	Processing paper chunk c20e8b3a9734f639c4e5aee42319e97331339e2b-abstract-chunk0000
# Processing paper c46db22a03406a765ffce2af1f55af7ce29e6070
# 	Split into 1 chunks
# 	Processing paper chunk c46db22a03406a765ffce2af1f55af7ce29e6070-abstract-chunk0000
# Processing paper c83b45b57b37b63f724b91aa890bcf74f24a8936
# 	Split into 1 chunks
# 	Processing paper chunk c83b45b57b37b63f724b91aa890bcf74f24a8936-abstract-chunk0000
# Processing paper e35e4a9f9764599503bca02c45786f1a2c76610d
# 	Split into 1 chunks
# 	Processing paper chunk e35e4a9f9764599503bca02c45786f1a2c76610d-abstract-chunk0000
# Processing paper e39d921a84e146b4b3cb8abba5c889cc34362e26
# 	Split into 1 chunks
# 	Processing paper chunk e39d921a84e146b4b3cb8abba5c889cc34362e26-abstract-chunk0000
# Processing paper eecd28eee7e4162b5cf26fe9ccce610abe4c8b1c
# 	Split into 1 chunks
# 	Processing paper chunk eecd28eee7e4162b5cf26fe9ccce610abe4c8b1c-abstract-chunk0000
# Processing paper f224c4a581c94ce771b23b780db251bb89a58a74
# 	Split into 1 chunks
# 	Processing paper chunk f224c4a581c94ce771b23b780db251bb89a58a74-abstract-chunk0000
# Processing paper f44c4519aa20598d0cf2a8078c3fbc78af09a9c5
# 	Split into 1 chunks
# 	Processing paper chunk f44c4519aa20598d0cf2a8078c3fbc78af09a9c5-abstract-chunk0000
# Processing paper f6b46b9d4d6261e4350c1a6e93f15218d5df73e3
# 	Split into 1 chunks
# 	Processing paper chunk f6b46b9d4d6261e4350c1a6e93f15218d5df73e3-abstract-chunk0000
# Processing paper f78fef46ef0a90d4934cb0366aa28bbb6996c809
# 	Split into 1 chunks
# 	Processing paper chunk f78fef46ef0a90d4934cb0366aa28bbb6996c809-abstract-chunk0000
# Processing paper 312cb3eab41c14ff1c232e9ed8785ee1a0490e0d
# 	Split into 1 chunks
# 	Processing paper chunk 312cb3eab41c14ff1c232e9ed8785ee1a0490e0d-abstract-chunk0000
# Processing paper 554fff95be0c4edba6870ce8621c7ccb35587f13
# 	Split into 1 chunks
# 	Processing paper chunk 554fff95be0c4edba6870ce8621c7ccb35587f13-abstract-chunk0000
# Processing paper 992b4fbf67db1965be791974c580ceb5a356f0b3
# 	Split into 1 chunks
# 	Processing paper chunk 992b4fbf67db1965be791974c580ceb5a356f0b3-abstract-chunk0000
# Processing paper bc36061fb7b77af754f0a27a8bb7e01bb1546d04
# 	Split into 1 chunks
# 	Processing paper chunk bc36061fb7b77af754f0a27a8bb7e01bb1546d04-abstract-chunk0000
# Processing paper c8d38f7aac70b108f4d0c04129d91b6e58b109ba
# 	Split into 1 chunks
# 	Processing paper chunk c8d38f7aac70b108f4d0c04129d91b6e58b109ba-abstract-chunk0000
# Processing paper bd996a9baada4e82290236e3985f979a27b55dc2
# 	Split into 1 chunks
# 	Processing paper chunk bd996a9baada4e82290236e3985f979a27b55dc2-abstract-chunk0000
# Processing paper c98929ab690a6c29d3402d4472e09770e1e89281
# 	Split into 1 chunks
# 	Processing paper chunk c98929ab690a6c29d3402d4472e09770e1e89281-abstract-chunk0000
# Processing paper d3bebfe3d7df045ed31031a37ee7319f218e583b
# 	Split into 1 chunks
# 	Processing paper chunk d3bebfe3d7df045ed31031a37ee7319f218e583b-abstract-chunk0000
# Processing paper 1a561f94de1d01bd9fef53c949a48e1e902985f0
# 	Split into 1 chunks
# 	Processing paper chunk 1a561f94de1d01bd9fef53c949a48e1e902985f0-abstract-chunk0000
# Processing paper 2aaf01e5831fb4b8577e38005fa66bf761e15b32
# 	Split into 1 chunks
# 	Processing paper chunk 2aaf01e5831fb4b8577e38005fa66bf761e15b32-abstract-chunk0000
# Processing paper 5b2880b492a0120fa73ea6990bd3cffa376e090f
# 	Split into 1 chunks
# 	Processing paper chunk 5b2880b492a0120fa73ea6990bd3cffa376e090f-abstract-chunk0000
# Processing paper 8a3a72e1244cd59ca4506206b5514ab31a520c1e
# 	Split into 1 chunks
# 	Processing paper chunk 8a3a72e1244cd59ca4506206b5514ab31a520c1e-abstract-chunk0000
# Processing paper b4786ad9cdbd690c97e69d2df95967fba1ae3adf
# 	Split into 1 chunks
# 	Processing paper chunk b4786ad9cdbd690c97e69d2df95967fba1ae3adf-abstract-chunk0000
# Processing paper ff72fde8819c5661228f9380050f6855a061e877
# 	Split into 1 chunks
# 	Processing paper chunk ff72fde8819c5661228f9380050f6855a061e877-abstract-chunk0000
# Processing paper 000cf8c93b9f3405a6e9249a59f71ae0fde11e06
# 	Split into 1 chunks
# 	Processing paper chunk 000cf8c93b9f3405a6e9249a59f71ae0fde11e06-abstract-chunk0000
# Processing paper 05a1be7a59445c35e172d8624edac25ba6fba7d1
# 	Split into 1 chunks
# 	Processing paper chunk 05a1be7a59445c35e172d8624edac25ba6fba7d1-abstract-chunk0000
# Processing paper 1600795f82aa10dc63d63dc4c24eb1b6ba10e34e
# 	Split into 1 chunks
# 	Processing paper chunk 1600795f82aa10dc63d63dc4c24eb1b6ba10e34e-abstract-chunk0000
# Processing paper 18146fab686834163417fb6c1da5da205c2edb68
# 	Split into 1 chunks
# 	Processing paper chunk 18146fab686834163417fb6c1da5da205c2edb68-abstract-chunk0000
# Processing paper 114f94215549bf6ee3ddf8ec91e728fc923f849b
# 	Split into 1 chunks
# 	Processing paper chunk 114f94215549bf6ee3ddf8ec91e728fc923f849b-abstract-chunk0000
# Processing paper 23dbe0abc08115ccfffa3d1db4c6c4c877aa518b
# 	Split into 1 chunks
# 	Processing paper chunk 23dbe0abc08115ccfffa3d1db4c6c4c877aa518b-abstract-chunk0000
# Processing paper 37347f2c04a07dc3dca4ec615f34a4cea63ea4d1
# 	Split into 1 chunks
# 	Processing paper chunk 37347f2c04a07dc3dca4ec615f34a4cea63ea4d1-abstract-chunk0000
# Processing paper 7f077cf6c76a8574ec2005b157b867655569a163
# 	Split into 1 chunks
# 	Processing paper chunk 7f077cf6c76a8574ec2005b157b867655569a163-abstract-chunk0000
# Processing paper b32338c44713b7c78fe114991616ed00e97da20c
# 	Split into 1 chunks
# 	Processing paper chunk b32338c44713b7c78fe114991616ed00e97da20c-abstract-chunk0000
# Processing paper bbc471f0c27fed5cdee35b2f962c5a6b1dc6f92c
# 	Split into 1 chunks
# 	Processing paper chunk bbc471f0c27fed5cdee35b2f962c5a6b1dc6f92c-abstract-chunk0000
# Processing paper c383cff48b89e71e310d71450dc2335e8e93aae8
# 	Split into 1 chunks
# 	Processing paper chunk c383cff48b89e71e310d71450dc2335e8e93aae8-abstract-chunk0000
# Processing paper e7562c7c55b25684e869a06c8dbeaafe46ed43c9
# 	Split into 1 chunks
# 	Processing paper chunk e7562c7c55b25684e869a06c8dbeaafe46ed43c9-abstract-chunk0000
# Processing paper 25d3018be561be360ef671072978145ea73a1149
# 	Split into 1 chunks
# 	Processing paper chunk 25d3018be561be360ef671072978145ea73a1149-abstract-chunk0000
# Processing paper a3114c133cbb8d7b088afbbc0fd4b6238de8e024
# 	Split into 1 chunks
# 	Processing paper chunk a3114c133cbb8d7b088afbbc0fd4b6238de8e024-abstract-chunk0000
# Processing paper a59da0e30bcfa1d18f120e625f96fa064ed08ca2
# 	Split into 1 chunks
# 	Processing paper chunk a59da0e30bcfa1d18f120e625f96fa064ed08ca2-abstract-chunk0000
# Processing paper cc87154e1c756489c4cf95d403166d316c083f71
# 	Split into 1 chunks
# 	Processing paper chunk cc87154e1c756489c4cf95d403166d316c083f71-abstract-chunk0000
# Processing paper 081a57f6920798e1238eea9d6b91e5bec0cf03e7
# 	Split into 1 chunks
# 	Processing paper chunk 081a57f6920798e1238eea9d6b91e5bec0cf03e7-abstract-chunk0000
# Processing paper 256a2227b79dd81a7bdf5295fc5537b4f78ec1cf
# 	Split into 1 chunks
# 	Processing paper chunk 256a2227b79dd81a7bdf5295fc5537b4f78ec1cf-abstract-chunk0000
# Processing paper 27269f2e55f2923f9acc6e8769fa9a8637b632cb
# 	Split into 1 chunks
# 	Processing paper chunk 27269f2e55f2923f9acc6e8769fa9a8637b632cb-abstract-chunk0000
# Processing paper 529b1e113cb9fb0c15998ba887a2d398d92137ca
# 	Split into 1 chunks
# 	Processing paper chunk 529b1e113cb9fb0c15998ba887a2d398d92137ca-abstract-chunk0000
# Processing paper 61bb06045d7d766e991b57473664aa4c05b406e6
# 	Split into 1 chunks
# 	Processing paper chunk 61bb06045d7d766e991b57473664aa4c05b406e6-abstract-chunk0000
# Processing paper e50b36766f964555e65fd7ef62ceff6d7dc79e51
# 	Split into 1 chunks
# 	Processing paper chunk e50b36766f964555e65fd7ef62ceff6d7dc79e51-abstract-chunk0000
# Processing paper f4f5a654e9f14d4f80f0f3c9b72e3b19daaeab46
# 	Split into 1 chunks
# 	Processing paper chunk f4f5a654e9f14d4f80f0f3c9b72e3b19daaeab46-abstract-chunk0000
# Processing paper 3ed2e29069fa425d877643018988ea85ffc27e4e
# 	Split into 1 chunks
# 	Processing paper chunk 3ed2e29069fa425d877643018988ea85ffc27e4e-abstract-chunk0000
# Processing paper 54840c7ffb4a1c57e105cdd5f5bc0e830b0d8161
# 	Split into 1 chunks
# 	Processing paper chunk 54840c7ffb4a1c57e105cdd5f5bc0e830b0d8161-abstract-chunk0000
# Processing paper 6c4268f699982a3d7f9407fd2dc6cb6ad5a687f0
# 	Split into 1 chunks
# 	Processing paper chunk 6c4268f699982a3d7f9407fd2dc6cb6ad5a687f0-abstract-chunk0000
# Processing paper 7d9a5517304e989e6045bbdc6f6619d34974f618
# 	Split into 1 chunks
# 	Processing paper chunk 7d9a5517304e989e6045bbdc6f6619d34974f618-abstract-chunk0000
# Processing paper 9025e25230f9addd7b6122c478ae798300feb5b0
# 	Split into 1 chunks
# 	Processing paper chunk 9025e25230f9addd7b6122c478ae798300feb5b0-abstract-chunk0000
# Processing paper b01428e61792fa7bef6f80baf7f6d6f6e7029117
# 	Split into 1 chunks
# 	Processing paper chunk b01428e61792fa7bef6f80baf7f6d6f6e7029117-abstract-chunk0000
# Processing paper bcfa782bfd5f7949a9023d950e576d5e11dc4a3e
# 	Split into 1 chunks
# 	Processing paper chunk bcfa782bfd5f7949a9023d950e576d5e11dc4a3e-abstract-chunk0000
# Processing paper d0c195bab3c4f95c9fa5d7ce35bd35175754f682
# 	Split into 1 chunks
# 	Processing paper chunk d0c195bab3c4f95c9fa5d7ce35bd35175754f682-abstract-chunk0000
# Processing paper e5f3d49d86dc1e9867dc49643bc5f865655d4769
# 	Split into 1 chunks
# 	Processing paper chunk e5f3d49d86dc1e9867dc49643bc5f865655d4769-abstract-chunk0000
# Processing paper e87180d9606acfe6c42330a13e14f62672da1692
# 	Split into 1 chunks
# 	Processing paper chunk e87180d9606acfe6c42330a13e14f62672da1692-abstract-chunk0000
# Processing paper ec5bb0e5615da07aadd6b04ef61573865ee7f506
# 	Split into 1 chunks
# 	Processing paper chunk ec5bb0e5615da07aadd6b04ef61573865ee7f506-abstract-chunk0000
# Processing paper f5606d8c8869fd8922b489a616e64696e7112b6e
# 	Split into 1 chunks
# 	Processing paper chunk f5606d8c8869fd8922b489a616e64696e7112b6e-abstract-chunk0000
# Processing paper fdfbabbd062e6654aa5fd4c2e8d5330e7df582ff
# 	Split into 1 chunks
# 	Processing paper chunk fdfbabbd062e6654aa5fd4c2e8d5330e7df582ff-abstract-chunk0000
# Processing paper 078fdb56698738891f47a310ef31d8504cb000b0
# 	Split into 2 chunks
# 	Processing paper chunk 078fdb56698738891f47a310ef31d8504cb000b0-abstract-chunk0000
# 	Processing paper chunk 078fdb56698738891f47a310ef31d8504cb000b0-abstract-chunk0001
# Processing paper 0dc321d2c3c5ef03b07a133d77e946a9813af368
# 	Split into 1 chunks
# 	Processing paper chunk 0dc321d2c3c5ef03b07a133d77e946a9813af368-abstract-chunk0000
# Processing paper 2421fa774d81383cf4ed38e40ad786fe1c9b4fc8
# 	Split into 1 chunks
# 	Processing paper chunk 2421fa774d81383cf4ed38e40ad786fe1c9b4fc8-abstract-chunk0000
# Processing paper 2597e188b4892fbf51167eebe2b0831263751df6
# 	Split into 1 chunks
# 	Processing paper chunk 2597e188b4892fbf51167eebe2b0831263751df6-abstract-chunk0000
# Processing paper 25d041cf4ed763a5884a5e8d88d1d7686715a4b8
# 	Split into 1 chunks
# 	Processing paper chunk 25d041cf4ed763a5884a5e8d88d1d7686715a4b8-abstract-chunk0000
# Processing paper 296da1c9daf014f6dc076912b9b5935690b2dfb5
# 	Split into 1 chunks
# 	Processing paper chunk 296da1c9daf014f6dc076912b9b5935690b2dfb5-abstract-chunk0000
# Processing paper 318b7263b1372edf569e4bf040a2cd0c7df59cb2
# 	Split into 1 chunks
# 	Processing paper chunk 318b7263b1372edf569e4bf040a2cd0c7df59cb2-abstract-chunk0000
# Processing paper 5be447d5bfbbeb8cdaeb706a7a98552fe78ecffd
# 	Split into 1 chunks
# 	Processing paper chunk 5be447d5bfbbeb8cdaeb706a7a98552fe78ecffd-abstract-chunk0000
# Processing paper 5ff6704f510d65e344024fd5ad3ae249708a6e19
# 	Split into 1 chunks
# 	Processing paper chunk 5ff6704f510d65e344024fd5ad3ae249708a6e19-abstract-chunk0000
# Processing paper 711cdcb3660d4a15b60b77b1a77ed9e8a0ee45b5
# 	Split into 1 chunks
# 	Processing paper chunk 711cdcb3660d4a15b60b77b1a77ed9e8a0ee45b5-abstract-chunk0000
# Processing paper 82366503be9e469546edb75f687ed3b141298aa4
# 	Split into 1 chunks
# 	Processing paper chunk 82366503be9e469546edb75f687ed3b141298aa4-abstract-chunk0000
# Processing paper 88e1be781a3bbd215e9e12a92f69cfcb8c9535ad
# 	Split into 2 chunks
# 	Processing paper chunk 88e1be781a3bbd215e9e12a92f69cfcb8c9535ad-abstract-chunk0000
# 	Processing paper chunk 88e1be781a3bbd215e9e12a92f69cfcb8c9535ad-abstract-chunk0001
# Processing paper 899ff3d25f8ba4b217d2a143ba13edb8c324bdfb
# 	Split into 1 chunks
# 	Processing paper chunk 899ff3d25f8ba4b217d2a143ba13edb8c324bdfb-abstract-chunk0000
# Processing paper 9a95591fbd9f9959f58fcf4a1040e2ab951ff7bc
# 	Split into 1 chunks
# 	Processing paper chunk 9a95591fbd9f9959f58fcf4a1040e2ab951ff7bc-abstract-chunk0000
# Processing paper a7e7c73c94270744b8982b758ed3be882e649411
# 	Split into 1 chunks
# 	Processing paper chunk a7e7c73c94270744b8982b758ed3be882e649411-abstract-chunk0000
# Processing paper 0fabd727b39c3d1e5a9f723d50baa279d9f4dca6
# 	Split into 1 chunks
# 	Processing paper chunk 0fabd727b39c3d1e5a9f723d50baa279d9f4dca6-abstract-chunk0000
# Processing paper 188765bf17cd80990389deeaae5c317536411be9
# 	Split into 1 chunks
# 	Processing paper chunk 188765bf17cd80990389deeaae5c317536411be9-abstract-chunk0000
# Processing paper 23fe03e47bcc4acbb06d82c113de8248c696fc76
# 	Split into 1 chunks
# ...
# 	Processing paper chunk 14d228f79774100f5182a311a517de857d9ceb6f-abstract-chunk0000
# Processing paper 154cfbaf732785aa4f9f7919c9ab2729f64cfd72
# 	Split into 1 chunks
# 	Processing paper chunk 154cfbaf732785aa4f9f7919c9ab2729f64cfd72-abstract-chunk0000
# Processing paper 155dbc6b92dacd354e78b4827f8491edc1b67fa0
# 	Split into 1 chunks
# 	Processing paper chunk 155dbc6b92dacd354e78b4827f8491edc1b67fa0-abstract-chunk0000
# Processing paper 156043f4d1706ca5b9fa8bc7cc3970179c828d78
# 	Split into 1 chunks
# 	Processing paper chunk 156043f4d1706ca5b9fa8bc7cc3970179c828d78-abstract-chunk0000
# Processing paper 1629532604fc0d77dd9eed778d6d6e9509413a1c
# 	Split into 1 chunks
# 	Processing paper chunk 1629532604fc0d77dd9eed778d6d6e9509413a1c-abstract-chunk0000
# Processing paper 169352320f2c92045179801413ff03f63f54dc20
# 	Split into 1 chunks
# 	Processing paper chunk 169352320f2c92045179801413ff03f63f54dc20-abstract-chunk0000
# Processing paper 16ac972b543ecb4b07524b6cc02a5653b3b0b4a3
# 	Split into 1 chunks
# 	Processing paper chunk 16ac972b543ecb4b07524b6cc02a5653b3b0b4a3-abstract-chunk0000
# Processing paper 16b7af1860b78390769a0483d2dc5c76e47f3ce8
# 	Split into 1 chunks
# 	Processing paper chunk 16b7af1860b78390769a0483d2dc5c76e47f3ce8-abstract-chunk0000
# Processing paper 16c58c3e4c516c2c8df2aaa19f1aacb86b198529
# 	Split into 1 chunks
# 	Processing paper chunk 16c58c3e4c516c2c8df2aaa19f1aacb86b198529-abstract-chunk0000
# Processing paper 16ed6652c26815837054a9582be5771a66ee7e01
# 	Split into 1 chunks
# 	Processing paper chunk 16ed6652c26815837054a9582be5771a66ee7e01-abstract-chunk0000
# Processing paper 16f6887d9b07440aced9736a25472f8d244d16a5
# 	Split into 1 chunks
# 	Processing paper chunk 16f6887d9b07440aced9736a25472f8d244d16a5-abstract-chunk0000
# Processing paper 1712992a250828196b4e196989adbdacb84b2750
# 	Split into 1 chunks
# 	Processing paper chunk 1712992a250828196b4e196989adbdacb84b2750-abstract-chunk0000
# Processing paper 177daf9ea812d67d28607bbdc93bcd685e527e04
# 	Split into 1 chunks
# 	Processing paper chunk 177daf9ea812d67d28607bbdc93bcd685e527e04-abstract-chunk0000
# Processing paper 17dd2266f1f704d4817b153e645348b7fe801d36
# 	Split into 1 chunks
# 	Processing paper chunk 17dd2266f1f704d4817b153e645348b7fe801d36-abstract-chunk0000
# Processing paper 180775ff9a9cbdac2ae32a69e73435866a9dbe2f
# 	Split into 1 chunks
# 	Processing paper chunk 180775ff9a9cbdac2ae32a69e73435866a9dbe2f-abstract-chunk0000
# Processing paper 1837d0a48625a8dd4922f9a1f93128d7a28a2c90
# 	Split into 1 chunks
# 	Processing paper chunk 1837d0a48625a8dd4922f9a1f93128d7a28a2c90-abstract-chunk0000
# Processing paper 1863efb7d23246582f45dabeaba44d070545deb8
# 	Split into 1 chunks
# 	Processing paper chunk 1863efb7d23246582f45dabeaba44d070545deb8-abstract-chunk0000
# Processing paper 18793826b1618ae6961d5d141e4706c16fdfc91b
# 	Split into 1 chunks
# 	Processing paper chunk 18793826b1618ae6961d5d141e4706c16fdfc91b-abstract-chunk0000
# Processing paper 18b6e2a6b5b4362d2049f9e586ff9b45460bece3
# 	Split into 1 chunks
# 	Processing paper chunk 18b6e2a6b5b4362d2049f9e586ff9b45460bece3-abstract-chunk0000
# Processing paper 18c591119328cabeb5ecc3cea54a64af29d1fd9a
# 	Split into 1 chunks
# 	Processing paper chunk 18c591119328cabeb5ecc3cea54a64af29d1fd9a-abstract-chunk0000
# Processing paper 19a476c588ca314a07e02c07f7422ea154ec67b7
# 	Split into 1 chunks
# 	Processing paper chunk 19a476c588ca314a07e02c07f7422ea154ec67b7-abstract-chunk0000
# Processing paper 19a51d85e9a8a6d2ebb7cf82543e5f0eff8ea983
# 	Split into 1 chunks
# 	Processing paper chunk 19a51d85e9a8a6d2ebb7cf82543e5f0eff8ea983-abstract-chunk0000
# Processing paper 1a04c6e82176fa57e8ba049df044d4ed7e2704b0
# 	Split into 1 chunks
# 	Processing paper chunk 1a04c6e82176fa57e8ba049df044d4ed7e2704b0-abstract-chunk0000
# Processing paper 1b4053f0faec24e209a178072df6ff166aab99d6
# 	Split into 1 chunks
# 	Processing paper chunk 1b4053f0faec24e209a178072df6ff166aab99d6-abstract-chunk0000
# Processing paper 1a26ca476af4c828fdc0971513ea515bcaff99b1
# 	Split into 1 chunks
# 	Processing paper chunk 1a26ca476af4c828fdc0971513ea515bcaff99b1-abstract-chunk0000
# Processing paper 1b35981aa9ef908ec426355d02a298781ec0d1c8
# 	Split into 1 chunks
# 	Processing paper chunk 1b35981aa9ef908ec426355d02a298781ec0d1c8-abstract-chunk0000
# Processing paper 1b56953aabcbbb7d30e120c948641d1807f6b861
# 	Split into 1 chunks
# 	Processing paper chunk 1b56953aabcbbb7d30e120c948641d1807f6b861-abstract-chunk0000
# Processing paper 1b951ec455572d04eb4121a8664fa4b6cef91636
# 	Split into 1 chunks
# 	Processing paper chunk 1b951ec455572d04eb4121a8664fa4b6cef91636-abstract-chunk0000
# Processing paper 1bb52b06b7ba638469bfd44abf052ba31e9a23f8
# 	Split into 1 chunks
# 	Processing paper chunk 1bb52b06b7ba638469bfd44abf052ba31e9a23f8-abstract-chunk0000
# Processing paper 1bd0b48aee7548d913e16ba887c5bc5242878825
# 	Split into 1 chunks
# 	Processing paper chunk 1bd0b48aee7548d913e16ba887c5bc5242878825-abstract-chunk0000
# Processing paper 1bd8fd658d72ada72854ac761d11035939f3d2b7
# 	Split into 1 chunks
# 	Processing paper chunk 1bd8fd658d72ada72854ac761d11035939f3d2b7-abstract-chunk0000
# Processing paper 1bf2d463deef907a6eb62b3055800569a6ae899c
# 	Split into 1 chunks
# 	Processing paper chunk 1bf2d463deef907a6eb62b3055800569a6ae899c-abstract-chunk0000
# Processing paper 1bfc8ad012e50f713ccddf6b8eca662314065ca1
# 	Split into 1 chunks
# 	Processing paper chunk 1bfc8ad012e50f713ccddf6b8eca662314065ca1-abstract-chunk0000
# Processing paper 1c643da4c98e1d4e06827c3142dd6bd06eb92731
# 	Split into 1 chunks
# 	Processing paper chunk 1c643da4c98e1d4e06827c3142dd6bd06eb92731-abstract-chunk0000
# Processing paper 1c7cddeb4978284b3f5154b4e4e62059a3df1145
# 	Split into 1 chunks
# 	Processing paper chunk 1c7cddeb4978284b3f5154b4e4e62059a3df1145-abstract-chunk0000
# Processing paper 1cd0018848ef0ffe332077a995500f7d23c93187
# 	Split into 2 chunks
# 	Processing paper chunk 1cd0018848ef0ffe332077a995500f7d23c93187-abstract-chunk0000
# 	Processing paper chunk 1cd0018848ef0ffe332077a995500f7d23c93187-abstract-chunk0001
# Processing paper 1cd0e8222b4ccee995b25a0de504a36d5d471317
# 	Split into 1 chunks
# 	Processing paper chunk 1cd0e8222b4ccee995b25a0de504a36d5d471317-abstract-chunk0000
# Processing paper 1cdf5095717052f0a98687ea33f4b793ab5d884c
# 	Split into 1 chunks
# 	Processing paper chunk 1cdf5095717052f0a98687ea33f4b793ab5d884c-abstract-chunk0000
# Processing paper 1ce5ced3f023cc546a7cfad2f6aaebf50718511e
# 	Split into 1 chunks
# 	Processing paper chunk 1ce5ced3f023cc546a7cfad2f6aaebf50718511e-abstract-chunk0000
# Processing paper 1d312661ef7c79ecf9d2cdcd24e3615f4b7e1832
# 	Split into 1 chunks
# 	Processing paper chunk 1d312661ef7c79ecf9d2cdcd24e3615f4b7e1832-abstract-chunk0000
# Processing paper 1d3824b6ab73f899e1ee847c4c14e50d0bab7858
# 	Split into 1 chunks
# 	Processing paper chunk 1d3824b6ab73f899e1ee847c4c14e50d0bab7858-abstract-chunk0000
# Processing paper 1e5c9694b16c35f42d8f30f783bc4a91ceb7d937
# 	Split into 1 chunks
# 	Processing paper chunk 1e5c9694b16c35f42d8f30f783bc4a91ceb7d937-abstract-chunk0000
# Processing paper 1ebacfdc1e6e840becb164182f98ef73df34c242
# 	Split into 1 chunks
# 	Processing paper chunk 1ebacfdc1e6e840becb164182f98ef73df34c242-abstract-chunk0000
# Processing paper 1ef59b7efec6531e57e9cf465f2737cf773cb4d7
# 	Split into 1 chunks
# 	Processing paper chunk 1ef59b7efec6531e57e9cf465f2737cf773cb4d7-abstract-chunk0000
# Processing paper 1f46459aa86ae05a9265298491b30c77e3f69dbb
# 	Split into 1 chunks
# 	Processing paper chunk 1f46459aa86ae05a9265298491b30c77e3f69dbb-abstract-chunk0000
# Processing paper 1f55f21d1aee501e56d6ef5ca05a3c87bd154722
# 	Split into 1 chunks
# 	Processing paper chunk 1f55f21d1aee501e56d6ef5ca05a3c87bd154722-abstract-chunk0000
# Processing paper 1f58c11b17551f18be5143d4be51fc66a1287356
# 	Split into 1 chunks
# 	Processing paper chunk 1f58c11b17551f18be5143d4be51fc66a1287356-abstract-chunk0000
# Processing paper 1f5cfde6e99f162a6e6dba391ed986b91da49b19
# 	Split into 1 chunks
# 	Processing paper chunk 1f5cfde6e99f162a6e6dba391ed986b91da49b19-abstract-chunk0000
# Processing paper 1f7d0eeb2d360618d63ee440b3e556b797650b64
# 	Split into 1 chunks
# 	Processing paper chunk 1f7d0eeb2d360618d63ee440b3e556b797650b64-abstract-chunk0000
# Processing paper 1f9ff53df377f58136add0424f08cd9eae56c362
# 	Split into 1 chunks
# 	Processing paper chunk 1f9ff53df377f58136add0424f08cd9eae56c362-abstract-chunk0000
# Processing paper 1fab7cb2ee0ed71e9af10349c2d79f5b4b77b1a9
# 	Split into 1 chunks
# 	Processing paper chunk 1fab7cb2ee0ed71e9af10349c2d79f5b4b77b1a9-abstract-chunk0000
# Processing paper 1fc6cc694939cdd316ed8be40fd399bf709b6108
# 	Split into 1 chunks
# 	Processing paper chunk 1fc6cc694939cdd316ed8be40fd399bf709b6108-abstract-chunk0000
# Processing paper 1fe0e4498ef06eeb692abc59e7cb38855e6d80d0
# 	Split into 1 chunks
# 	Processing paper chunk 1fe0e4498ef06eeb692abc59e7cb38855e6d80d0-abstract-chunk0000
# Processing paper 201a5af0ca50f193b1d0022157685a04db6c50ad
# 	Split into 1 chunks
# 	Processing paper chunk 201a5af0ca50f193b1d0022157685a04db6c50ad-abstract-chunk0000
# Processing paper 2024f6c043cc25b6717ce7ce2f50b4af2df14018
# 	Split into 1 chunks
# 	Processing paper chunk 2024f6c043cc25b6717ce7ce2f50b4af2df14018-abstract-chunk0000
# Processing paper 204bfa0bb5ba00c9801c66334ea048cba501f47a
# 	Split into 1 chunks
# 	Processing paper chunk 204bfa0bb5ba00c9801c66334ea048cba501f47a-abstract-chunk0000
# Processing paper 207943fe865503068095e8d4dda79d16e0d02eb7
# 	Split into 1 chunks
# 	Processing paper chunk 207943fe865503068095e8d4dda79d16e0d02eb7-abstract-chunk0000
# Processing paper 20ac767e1d3eb0035428fefe3ea83095a5e281db
# 	Split into 2 chunks
# 	Processing paper chunk 20ac767e1d3eb0035428fefe3ea83095a5e281db-abstract-chunk0000
# 	Processing paper chunk 20ac767e1d3eb0035428fefe3ea83095a5e281db-abstract-chunk0001
# Processing paper 20cc7f0676b5a01158a24595776debdaa1d5ed05
# 	Split into 1 chunks
# 	Processing paper chunk 20cc7f0676b5a01158a24595776debdaa1d5ed05-abstract-chunk0000
# Processing paper 2115420cb687ff41893be6750ac405a569c6fdb7
# 	Split into 1 chunks
# 	Processing paper chunk 2115420cb687ff41893be6750ac405a569c6fdb7-abstract-chunk0000
# Processing paper 21676eb20dbf95723efc1f5e3497f79c69c26c7d
# 	Split into 1 chunks
# 	Processing paper chunk 21676eb20dbf95723efc1f5e3497f79c69c26c7d-abstract-chunk0000
# Processing paper 21821eec41e9ab18fba67cb26b9baaa48a695f82
# 	Split into 1 chunks
# 	Processing paper chunk 21821eec41e9ab18fba67cb26b9baaa48a695f82-abstract-chunk0000
# Processing paper 21b7938e607c9d454e7341ef9f80fdd2c40cd887
# 	Split into 1 chunks
# 	Processing paper chunk 21b7938e607c9d454e7341ef9f80fdd2c40cd887-abstract-chunk0000
# Processing paper 21fabdc871352fbbaa049ef6c5f6b3beda288828
# 	Split into 1 chunks
# 	Processing paper chunk 21fabdc871352fbbaa049ef6c5f6b3beda288828-abstract-chunk0000
# Processing paper 225278c096c276dfe554a6ac075f4c66a231a893
# 	Split into 1 chunks
# 	Processing paper chunk 225278c096c276dfe554a6ac075f4c66a231a893-abstract-chunk0000
# Processing paper 226a42280f141a6ca553aadadb6c09f48a4819a6
# 	Split into 1 chunks
# 	Processing paper chunk 226a42280f141a6ca553aadadb6c09f48a4819a6-abstract-chunk0000
# Processing paper 226cec8b96ec5015d524b0d1f0d724a1dbd50f19
# 	Split into 2 chunks
# 	Processing paper chunk 226cec8b96ec5015d524b0d1f0d724a1dbd50f19-abstract-chunk0000
# 	Processing paper chunk 226cec8b96ec5015d524b0d1f0d724a1dbd50f19-abstract-chunk0001
# Processing paper 22dd9bd4ae43deebe114fde6efc0eea435daa118
# 	Split into 1 chunks
# 	Processing paper chunk 22dd9bd4ae43deebe114fde6efc0eea435daa118-abstract-chunk0000
# Processing paper 235ba3ca6e546e326d3cb7c3b57acfaeba11fcb6
# 	Split into 1 chunks
# 	Processing paper chunk 235ba3ca6e546e326d3cb7c3b57acfaeba11fcb6-abstract-chunk0000
# Processing paper 23d0bf524fc9065cfca07b532d0c57830a7db882
# 	Split into 1 chunks
# 	Processing paper chunk 23d0bf524fc9065cfca07b532d0c57830a7db882-abstract-chunk0000
# Processing paper 2420f2348b70b29d6981afa7749c955b6a44c427
# 	Split into 1 chunks
# 	Processing paper chunk 2420f2348b70b29d6981afa7749c955b6a44c427-abstract-chunk0000
# Processing paper 24a404ce812ba24a3fab1f21cd98d958a6faa330
# 	Split into 1 chunks
# 	Processing paper chunk 24a404ce812ba24a3fab1f21cd98d958a6faa330-abstract-chunk0000
# Processing paper 25597b0013367504ef5a011ee1e7e8257df2169c
# 	Split into 1 chunks
# 	Processing paper chunk 25597b0013367504ef5a011ee1e7e8257df2169c-abstract-chunk0000
# Processing paper 2583e14cba27d20dbc0f515f16cc887300c4bc47
# 	Split into 1 chunks
# 	Processing paper chunk 2583e14cba27d20dbc0f515f16cc887300c4bc47-abstract-chunk0000
# Processing paper 25f1255baa1766165c27df1c83ba84756766186d
# 	Split into 1 chunks
# 	Processing paper chunk 25f1255baa1766165c27df1c83ba84756766186d-abstract-chunk0000
# Processing paper 269e210507c2afe79c9f06809c7d001bbc0a8609
# 	Split into 2 chunks
# 	Processing paper chunk 269e210507c2afe79c9f06809c7d001bbc0a8609-abstract-chunk0000
# 	Processing paper chunk 269e210507c2afe79c9f06809c7d001bbc0a8609-abstract-chunk0001
# Processing paper 26b1ad2977b1593dac098e65577d8acef0009e99
# 	Split into 1 chunks
# 	Processing paper chunk 26b1ad2977b1593dac098e65577d8acef0009e99-abstract-chunk0000
# Processing paper 2718426d026cb1a1051e7fc42fc1471c765cf0d1
# 	Split into 1 chunks
# 	Processing paper chunk 2718426d026cb1a1051e7fc42fc1471c765cf0d1-abstract-chunk0000
# Processing paper 282da2a35d53ba9c1316cdbfca526d8e5afe67e5
# 	Split into 2 chunks
# 	Processing paper chunk 282da2a35d53ba9c1316cdbfca526d8e5afe67e5-abstract-chunk0000
# 	Processing paper chunk 282da2a35d53ba9c1316cdbfca526d8e5afe67e5-abstract-chunk0001
# Processing paper 2839090634de44777a3bf4a230dc701ff39bd9c4
# 	Split into 1 chunks
# 	Processing paper chunk 2839090634de44777a3bf4a230dc701ff39bd9c4-abstract-chunk0000
# Processing paper 28f19b2a73e2afe3e31092373aa4b60cf85e740d
# 	Split into 1 chunks
# 	Processing paper chunk 28f19b2a73e2afe3e31092373aa4b60cf85e740d-abstract-chunk0000
# Processing paper 293a90a3e769ffc7017d40795d75e73891d411ff
# 	Split into 1 chunks
# 	Processing paper chunk 293a90a3e769ffc7017d40795d75e73891d411ff-abstract-chunk0000
# Processing paper 29424566c408129f88859dcafc4813dad93391b9
# 	Split into 1 chunks
# 	Processing paper chunk 29424566c408129f88859dcafc4813dad93391b9-abstract-chunk0000
# Processing paper 297ff6f2c5dfeeef0f93bd242944324d865e0f61
# 	Split into 1 chunks
# 	Processing paper chunk 297ff6f2c5dfeeef0f93bd242944324d865e0f61-abstract-chunk0000
# Processing paper 2a2895fcdb1a465b690a9c7c36243d727974dd8d
# 	Split into 1 chunks
# 	Processing paper chunk 2a2895fcdb1a465b690a9c7c36243d727974dd8d-abstract-chunk0000
# Processing paper 2a94398578b5dd56d19d70eb09cbe75c4e1daa89
# 	Split into 1 chunks
# 	Processing paper chunk 2a94398578b5dd56d19d70eb09cbe75c4e1daa89-abstract-chunk0000
# Processing paper 2b424b0c22ce7d55d5fb3fe6ce1e4a28905f7266
# 	Split into 1 chunks
# 	Processing paper chunk 2b424b0c22ce7d55d5fb3fe6ce1e4a28905f7266-abstract-chunk0000
# Processing paper 2ba883a237b17a6f43e42cefc8157218e50a89a5
# 	Split into 1 chunks
# 	Processing paper chunk 2ba883a237b17a6f43e42cefc8157218e50a89a5-abstract-chunk0000
# Processing paper 2c2a6ddaf0b36f71ef8124fa6a4e30c457e71dcd
# 	Split into 1 chunks
# 	Processing paper chunk 2c2a6ddaf0b36f71ef8124fa6a4e30c457e71dcd-abstract-chunk0000
# Processing paper 2c5c892a97169f37b69fbbfec28f35a534d85443
# 	Split into 1 chunks
# 	Processing paper chunk 2c5c892a97169f37b69fbbfec28f35a534d85443-abstract-chunk0000
# Processing paper 2c970f3bcac332c228917058628bc397e4757c95
# 	Split into 1 chunks
# 	Processing paper chunk 2c970f3bcac332c228917058628bc397e4757c95-abstract-chunk0000
# Processing paper 2d5d5ba45ce49907e8a104b95b724a702112673b
# 	Split into 1 chunks
# 	Processing paper chunk 2d5d5ba45ce49907e8a104b95b724a702112673b-abstract-chunk0000
# Processing paper 2e19de9399fcddf7042b82e5143414fdaffe54fe
# 	Split into 1 chunks
# 	Processing paper chunk 2e19de9399fcddf7042b82e5143414fdaffe54fe-abstract-chunk0000
# Processing paper 2e33e5d35f9a8d5b6a2f4091c6e2d22cb1c70a24
# 	Split into 1 chunks
# 	Processing paper chunk 2e33e5d35f9a8d5b6a2f4091c6e2d22cb1c70a24-abstract-chunk0000
# Processing paper 2e570f74934f171bef8684ff3a3672bd65668b0c
# 	Split into 1 chunks
# 	Processing paper chunk 2e570f74934f171bef8684ff3a3672bd65668b0c-abstract-chunk0000
# Processing paper 2e6c6d723d695de9577681a54c66475873df6391
# 	Split into 1 chunks
# 	Processing paper chunk 2e6c6d723d695de9577681a54c66475873df6391-abstract-chunk0000

# %% [markdown]
# - Create a uniqueness constraint to avoid duplicate chunks

# %%
kg.query("""
CREATE CONSTRAINT unique_chunk IF NOT EXISTS
    FOR (c:Chunk) REQUIRE c.chunkId IS UNIQUE
""")
# Out:
# []

# %%
kg.query("SHOW INDEXES")
# Out:
# [{'id': 11,
#   'name': 'abstract_chunks',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'VECTOR',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['textEmbedding'],
#   'indexProvider': 'vector-2.0',
#   'owningConstraint': None,
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 33, 52, 774000000, tzinfo=<UTC>),
#   'readCount': 2},
#  {'id': 1,
#   'name': 'index_343aff4e',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'LOOKUP',
#   'entityType': 'NODE',
#   'labelsOrTypes': None,
#   'properties': None,
#   'indexProvider': 'token-lookup-1.0',
#   'owningConstraint': None,
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 37, 16, 996000000, tzinfo=<UTC>),
#   'readCount': 39406},
#  {'id': 2,
#   'name': 'index_f7700477',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'LOOKUP',
#   'entityType': 'RELATIONSHIP',
#   'labelsOrTypes': None,
#   'properties': None,
#   'indexProvider': 'token-lookup-1.0',
#   'owningConstraint': None,
#   'lastRead': None,
#   'readCount': 0},
#  {'id': 5,
#   'name': 'unique_author',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Author'],
#   'properties': ['author'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_author',
#   'lastRead': None,
#   'readCount': 0},
#  {'id': 9,
#   'name': 'unique_chunk',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['chunkId'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_chunk',
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 37, 23, 481000000, tzinfo=<UTC>),
#   'readCount': 6},
#  {'id': 3,
#   'name': 'unique_paper',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Paper'],
#   'properties': ['paperId'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_paper',
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 6, 18, 572000000, tzinfo=<UTC>),
#   'readCount': 78738},
#  {'id': 7,
#   'name': 'unique_venue',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Venue'],
#   'properties': ['venueId'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_venue',
#   'lastRead': None,
#   'readCount': 0}]

# %% [markdown]
# - Loop through and create nodes for all chunks
# - Should create 23 nodes because you set a limit of 20 chunks in the text splitting function above

# %%
node_count = 0
for paper in papers:
    print(f'Processing paper {paper["paperId"]}')
    chunks = split_paper_abstract(paper)
    for chunk in chunks:
        print(f'\tProcessing paper chunk {chunk["chunkId"]}')
        kg.query(merge_chunk_node_query,
                params={
                    'chunkParam': chunk
                })
        node_count += 1
print(f"Created {node_count} nodes")
# Out:
# Processing paper 1e5cd344430d8de5bdb866ea5e8612467e69b689
# 	Split into 1 chunks
# 	Processing paper chunk 1e5cd344430d8de5bdb866ea5e8612467e69b689-abstract-chunk0000
# Processing paper c85acc8c6ac5eb7466e26517ae33aeac6fec6689
# 	Split into 1 chunks
# 	Processing paper chunk c85acc8c6ac5eb7466e26517ae33aeac6fec6689-abstract-chunk0000
# Processing paper bd5ae6e3dd85b54442c70701f6b19a35891423f0
# 	Split into 1 chunks
# 	Processing paper chunk bd5ae6e3dd85b54442c70701f6b19a35891423f0-abstract-chunk0000
# Processing paper eaeeb3c3d6726464ead8561082a7d72d8e7a0d64
# 	Split into 1 chunks
# 	Processing paper chunk eaeeb3c3d6726464ead8561082a7d72d8e7a0d64-abstract-chunk0000
# Processing paper 1432bfc59b9de4fd02554be99f181e2db4e10f37
# 	Split into 1 chunks
# 	Processing paper chunk 1432bfc59b9de4fd02554be99f181e2db4e10f37-abstract-chunk0000
# Processing paper 49ac1b055ed8da31193644c868b3173ed3e2a24f
# 	Split into 1 chunks
# 	Processing paper chunk 49ac1b055ed8da31193644c868b3173ed3e2a24f-abstract-chunk0000
# Processing paper 8658bf3b526cd2688f1ebaac1d2ab7a905444233
# 	Split into 1 chunks
# 	Processing paper chunk 8658bf3b526cd2688f1ebaac1d2ab7a905444233-abstract-chunk0000
# Processing paper d18f5997551c02196cd8d41b1f007191b4893013
# 	Split into 1 chunks
# 	Processing paper chunk d18f5997551c02196cd8d41b1f007191b4893013-abstract-chunk0000
# Processing paper 138cdc9ebc1583e4e6a7c7d5596570a620c95800
# 	Split into 1 chunks
# 	Processing paper chunk 138cdc9ebc1583e4e6a7c7d5596570a620c95800-abstract-chunk0000
# Processing paper 3bed780ecbd934b1bdf8320f278ffc6dd4e3f827
# 	Split into 1 chunks
# 	Processing paper chunk 3bed780ecbd934b1bdf8320f278ffc6dd4e3f827-abstract-chunk0000
# Processing paper 9d0bb088a57c274c84d08b7f4fe106140c18f35b
# 	Split into 2 chunks
# 	Processing paper chunk 9d0bb088a57c274c84d08b7f4fe106140c18f35b-abstract-chunk0000
# 	Processing paper chunk 9d0bb088a57c274c84d08b7f4fe106140c18f35b-abstract-chunk0001
# Processing paper b46b1952160ba7a5ecd7b05e4cedb9d0c8f6ec12
# 	Split into 1 chunks
# 	Processing paper chunk b46b1952160ba7a5ecd7b05e4cedb9d0c8f6ec12-abstract-chunk0000
# Processing paper 0edeae6f5f4abbc72608b2e722c025d283658181
# 	Split into 1 chunks
# 	Processing paper chunk 0edeae6f5f4abbc72608b2e722c025d283658181-abstract-chunk0000
# Processing paper 60c3b0a6e0769644c13db6a5cb9134a93efe22bb
# 	Split into 1 chunks
# 	Processing paper chunk 60c3b0a6e0769644c13db6a5cb9134a93efe22bb-abstract-chunk0000
# Processing paper c3ca195966c089642bb94f053c2ca135af068f8f
# 	Split into 1 chunks
# 	Processing paper chunk c3ca195966c089642bb94f053c2ca135af068f8f-abstract-chunk0000
# Processing paper c5104a148dfd34604ce2b58207a81ce0d46f6bc3
# 	Split into 1 chunks
# 	Processing paper chunk c5104a148dfd34604ce2b58207a81ce0d46f6bc3-abstract-chunk0000
# Processing paper 0ce4984341853d7a35815bc61b7d217bee3e9b93
# 	Split into 1 chunks
# 	Processing paper chunk 0ce4984341853d7a35815bc61b7d217bee3e9b93-abstract-chunk0000
# Processing paper 895ccbdd77ff7461f53c90b745ce70a58b0a9fa7
# 	Split into 1 chunks
# 	Processing paper chunk 895ccbdd77ff7461f53c90b745ce70a58b0a9fa7-abstract-chunk0000
# Processing paper 6f6f9b459a75932754b993a308acdd986e0cbdfa
# 	Split into 1 chunks
# 	Processing paper chunk 6f6f9b459a75932754b993a308acdd986e0cbdfa-abstract-chunk0000
# Processing paper c7a21aa3b201412e786b32badc812af30ddaae2f
# 	Split into 1 chunks
# 	Processing paper chunk c7a21aa3b201412e786b32badc812af30ddaae2f-abstract-chunk0000
# Processing paper f69db4835380537de40c4a3d536ef989c0bd9119
# 	Split into 1 chunks
# 	Processing paper chunk f69db4835380537de40c4a3d536ef989c0bd9119-abstract-chunk0000
# Processing paper 4d820d28ed91626ebb4078cb26f88d5c06dc4714
# 	Split into 1 chunks
# 	Processing paper chunk 4d820d28ed91626ebb4078cb26f88d5c06dc4714-abstract-chunk0000
# Processing paper 688c2ac32a7e6ee31942eee0f0f931a0e44dc84e
# 	Split into 1 chunks
# 	Processing paper chunk 688c2ac32a7e6ee31942eee0f0f931a0e44dc84e-abstract-chunk0000
# Processing paper 494054a886a67882546c551877d3d76966054870
# 	Split into 1 chunks
# 	Processing paper chunk 494054a886a67882546c551877d3d76966054870-abstract-chunk0000
# Processing paper 402ef3c2f82c199daae9d3d68bf1ccd54459115a
# 	Split into 1 chunks
# 	Processing paper chunk 402ef3c2f82c199daae9d3d68bf1ccd54459115a-abstract-chunk0000
# Processing paper 9438d1dd8a3c414d7d5c135ebbe60927826d8e5b
# 	Split into 1 chunks
# 	Processing paper chunk 9438d1dd8a3c414d7d5c135ebbe60927826d8e5b-abstract-chunk0000
# Processing paper e44b43c23bba16818a04fb74925d5b0548737377
# 	Split into 1 chunks
# 	Processing paper chunk e44b43c23bba16818a04fb74925d5b0548737377-abstract-chunk0000
# Processing paper 8a06f779d8dcb5114acfec9624cc8217575f355f
# 	Split into 1 chunks
# 	Processing paper chunk 8a06f779d8dcb5114acfec9624cc8217575f355f-abstract-chunk0000
# Processing paper 909aa833954a0d1df6dd1bf6856fdf0770e3f099
# 	Split into 1 chunks
# 	Processing paper chunk 909aa833954a0d1df6dd1bf6856fdf0770e3f099-abstract-chunk0000
# Processing paper 68d3c87d3420fa81ef71096fd07ec43710ed260b
# 	Split into 1 chunks
# 	Processing paper chunk 68d3c87d3420fa81ef71096fd07ec43710ed260b-abstract-chunk0000
# Processing paper 417e51e98cd4c9431dcb2fa536636bed065e34ad
# 	Split into 1 chunks
# 	Processing paper chunk 417e51e98cd4c9431dcb2fa536636bed065e34ad-abstract-chunk0000
# Processing paper 6bf683500e8e9efd92add4e167f8959b5b7ecb4f
# 	Split into 1 chunks
# 	Processing paper chunk 6bf683500e8e9efd92add4e167f8959b5b7ecb4f-abstract-chunk0000
# Processing paper 14227916796d504100ec20af8df0abe95df78afb
# 	Split into 1 chunks
# 	Processing paper chunk 14227916796d504100ec20af8df0abe95df78afb-abstract-chunk0000
# Processing paper bdf4e7d440f3f159e7209693fa20298fe9781ad1
# 	Split into 1 chunks
# 	Processing paper chunk bdf4e7d440f3f159e7209693fa20298fe9781ad1-abstract-chunk0000
# Processing paper 5b4add946a9373dbf8c279ea7ad848873c6a8b1a
# 	Split into 1 chunks
# 	Processing paper chunk 5b4add946a9373dbf8c279ea7ad848873c6a8b1a-abstract-chunk0000
# Processing paper 16f2eacb46b33ab6e9d65d6da74be84f7fb6bb88
# 	Split into 1 chunks
# 	Processing paper chunk 16f2eacb46b33ab6e9d65d6da74be84f7fb6bb88-abstract-chunk0000
# Processing paper 3206440e7b5861d7ad6cb2c4369f6c27103f4c76
# 	Split into 1 chunks
# 	Processing paper chunk 3206440e7b5861d7ad6cb2c4369f6c27103f4c76-abstract-chunk0000
# Processing paper 7b66f2e39ba0fb763969538cf224d23e9670a4fc
# 	Split into 2 chunks
# 	Processing paper chunk 7b66f2e39ba0fb763969538cf224d23e9670a4fc-abstract-chunk0000
# 	Processing paper chunk 7b66f2e39ba0fb763969538cf224d23e9670a4fc-abstract-chunk0001
# Processing paper f758bf13e1439fa1316f645d53cd89cc85b01404
# 	Split into 1 chunks
# 	Processing paper chunk f758bf13e1439fa1316f645d53cd89cc85b01404-abstract-chunk0000
# Processing paper b1a58e73360f2df57429a52d6ef98161c064887a
# 	Split into 1 chunks
# 	Processing paper chunk b1a58e73360f2df57429a52d6ef98161c064887a-abstract-chunk0000
# Processing paper 264315fd4f926968683dacec0fbfc5632e4c65d7
# 	Split into 1 chunks
# 	Processing paper chunk 264315fd4f926968683dacec0fbfc5632e4c65d7-abstract-chunk0000
# Processing paper 6fd4f44d283fce0dc14aa2fd0323d86ab750df36
# 	Split into 1 chunks
# 	Processing paper chunk 6fd4f44d283fce0dc14aa2fd0323d86ab750df36-abstract-chunk0000
# Processing paper e9e5deb482fc598a0cc89ec5b952ceb04fe172a3
# 	Split into 1 chunks
# 	Processing paper chunk e9e5deb482fc598a0cc89ec5b952ceb04fe172a3-abstract-chunk0000
# Processing paper 2dc393fe8a708f99cf5d872d61f026c56588844c
# 	Split into 1 chunks
# 	Processing paper chunk 2dc393fe8a708f99cf5d872d61f026c56588844c-abstract-chunk0000
# Processing paper ef40cd6587e8528a536f95c98a6ea6a96cab53a4
# 	Split into 1 chunks
# 	Processing paper chunk ef40cd6587e8528a536f95c98a6ea6a96cab53a4-abstract-chunk0000
# Processing paper c58d20ab97c3a06040e33034af08fcc2f5c9c35f
# 	Split into 1 chunks
# 	Processing paper chunk c58d20ab97c3a06040e33034af08fcc2f5c9c35f-abstract-chunk0000
# Processing paper e4f0c1331abfec2ca1f37ca569a78ea056676aae
# 	Split into 1 chunks
# 	Processing paper chunk e4f0c1331abfec2ca1f37ca569a78ea056676aae-abstract-chunk0000
# Processing paper 42b97316776c820340c81128fb9832188f10dbef
# 	Split into 1 chunks
# 	Processing paper chunk 42b97316776c820340c81128fb9832188f10dbef-abstract-chunk0000
# Processing paper d00e68e4a2f059e1e1197905a2b21f41aee201ac
# 	Split into 1 chunks
# 	Processing paper chunk d00e68e4a2f059e1e1197905a2b21f41aee201ac-abstract-chunk0000
# Processing paper e9d4e251337fabd1187482f706b3b8109203eb7d
# 	Split into 1 chunks
# 	Processing paper chunk e9d4e251337fabd1187482f706b3b8109203eb7d-abstract-chunk0000
# Processing paper 0748101ba2ae5511bb35cdc9c889f39115017f8a
# 	Split into 1 chunks
# 	Processing paper chunk 0748101ba2ae5511bb35cdc9c889f39115017f8a-abstract-chunk0000
# Processing paper 552f070fbcd943e688d40cf295adb80e1ec8a18b
# 	Split into 2 chunks
# 	Processing paper chunk 552f070fbcd943e688d40cf295adb80e1ec8a18b-abstract-chunk0000
# 	Processing paper chunk 552f070fbcd943e688d40cf295adb80e1ec8a18b-abstract-chunk0001
# Processing paper c04ca48ad26d70ede688994b2ecc32920de61752
# 	Split into 2 chunks
# 	Processing paper chunk c04ca48ad26d70ede688994b2ecc32920de61752-abstract-chunk0000
# 	Processing paper chunk c04ca48ad26d70ede688994b2ecc32920de61752-abstract-chunk0001
# Processing paper 18de50c46903ea51ded05c1e944797178bd04214
# 	Split into 1 chunks
# 	Processing paper chunk 18de50c46903ea51ded05c1e944797178bd04214-abstract-chunk0000
# Processing paper 6c81fb14c2bf4af42f1ccdb28b25a3c1efe77607
# 	Split into 2 chunks
# 	Processing paper chunk 6c81fb14c2bf4af42f1ccdb28b25a3c1efe77607-abstract-chunk0000
# 	Processing paper chunk 6c81fb14c2bf4af42f1ccdb28b25a3c1efe77607-abstract-chunk0001
# Processing paper cd22748274a3927d455f832e64c56d7c508d6f86
# 	Split into 1 chunks
# 	Processing paper chunk cd22748274a3927d455f832e64c56d7c508d6f86-abstract-chunk0000
# Processing paper bd974347fe39425bb83a5e1ae318d54b1ad60b07
# 	Split into 1 chunks
# 	Processing paper chunk bd974347fe39425bb83a5e1ae318d54b1ad60b07-abstract-chunk0000
# Processing paper 87d921ccfbfc933f89fdf2cec445e5004d7a7aa4
# 	Split into 1 chunks
# 	Processing paper chunk 87d921ccfbfc933f89fdf2cec445e5004d7a7aa4-abstract-chunk0000
# Processing paper 6382084de434ece986a5733037b7d9195dd9ecae
# 	Split into 1 chunks
# 	Processing paper chunk 6382084de434ece986a5733037b7d9195dd9ecae-abstract-chunk0000
# Processing paper ee0aa1181dcb6d6189f0c3927b678cfbd81c4b94
# 	Split into 1 chunks
# 	Processing paper chunk ee0aa1181dcb6d6189f0c3927b678cfbd81c4b94-abstract-chunk0000
# Processing paper fe9483fd4c28aa042e9682d01fd8bb35a67ec0a9
# 	Split into 1 chunks
# 	Processing paper chunk fe9483fd4c28aa042e9682d01fd8bb35a67ec0a9-abstract-chunk0000
# Processing paper 3b5668acf61908d47cbae22df0c1504f2a01d497
# 	Split into 1 chunks
# 	Processing paper chunk 3b5668acf61908d47cbae22df0c1504f2a01d497-abstract-chunk0000
# Processing paper 836ef53b85b2e650b3b4d54caf96fe2d3ed97161
# 	Split into 1 chunks
# 	Processing paper chunk 836ef53b85b2e650b3b4d54caf96fe2d3ed97161-abstract-chunk0000
# Processing paper 461983d1765968582e083d3947c655dfa2f27e91
# 	Split into 2 chunks
# 	Processing paper chunk 461983d1765968582e083d3947c655dfa2f27e91-abstract-chunk0000
# 	Processing paper chunk 461983d1765968582e083d3947c655dfa2f27e91-abstract-chunk0001
# Processing paper 3b6f2e36382eb067c979a1d85d860a65b871bfa6
# 	Split into 1 chunks
# 	Processing paper chunk 3b6f2e36382eb067c979a1d85d860a65b871bfa6-abstract-chunk0000
# Processing paper ca52609c27feac84dc581058013dc8bbb06c8411
# 	Split into 1 chunks
# 	Processing paper chunk ca52609c27feac84dc581058013dc8bbb06c8411-abstract-chunk0000
# Processing paper 57219e8e0f479f0f7ef61c33aae0c1fe7326153b
# 	Split into 2 chunks
# 	Processing paper chunk 57219e8e0f479f0f7ef61c33aae0c1fe7326153b-abstract-chunk0000
# 	Processing paper chunk 57219e8e0f479f0f7ef61c33aae0c1fe7326153b-abstract-chunk0001
# Processing paper 74b6330b0e0f24d7bca84ff178835aa21d760770
# 	Split into 1 chunks
# 	Processing paper chunk 74b6330b0e0f24d7bca84ff178835aa21d760770-abstract-chunk0000
# Processing paper bb04b7d3fe8a340aa4c333550b1659162f355c29
# 	Split into 2 chunks
# 	Processing paper chunk bb04b7d3fe8a340aa4c333550b1659162f355c29-abstract-chunk0000
# 	Processing paper chunk bb04b7d3fe8a340aa4c333550b1659162f355c29-abstract-chunk0001
# Processing paper 10869423891a9249d23eec9b55f89a02e0580b16
# 	Split into 1 chunks
# 	Processing paper chunk 10869423891a9249d23eec9b55f89a02e0580b16-abstract-chunk0000
# Processing paper 459a4362980327424f6b317230911274cf009a46
# 	Split into 2 chunks
# 	Processing paper chunk 459a4362980327424f6b317230911274cf009a46-abstract-chunk0000
# 	Processing paper chunk 459a4362980327424f6b317230911274cf009a46-abstract-chunk0001
# Processing paper 63aed5135bf873a071ecae0a44d1eb666a18de80
# 	Split into 1 chunks
# 	Processing paper chunk 63aed5135bf873a071ecae0a44d1eb666a18de80-abstract-chunk0000
# Processing paper 80304266f19512f7765045337600f897b60b5533
# 	Split into 1 chunks
# 	Processing paper chunk 80304266f19512f7765045337600f897b60b5533-abstract-chunk0000
# Processing paper 8fa72f04358eab415af993fffaecd903eafd8a58
# 	Split into 1 chunks
# 	Processing paper chunk 8fa72f04358eab415af993fffaecd903eafd8a58-abstract-chunk0000
# Processing paper cccd136bb629869abd07815f6ba53bbf3725a63f
# 	Split into 1 chunks
# 	Processing paper chunk cccd136bb629869abd07815f6ba53bbf3725a63f-abstract-chunk0000
# Processing paper 015c446ac0e884330aa08a971c280b30352fcd87
# 	Split into 1 chunks
# 	Processing paper chunk 015c446ac0e884330aa08a971c280b30352fcd87-abstract-chunk0000
# Processing paper 2274f4f4604d25d7ad9a6eb222ac6573da7f11d7
# 	Split into 1 chunks
# 	Processing paper chunk 2274f4f4604d25d7ad9a6eb222ac6573da7f11d7-abstract-chunk0000
# Processing paper 2f509202b5006d75a50efec01a8dcac19efb3af6
# 	Split into 1 chunks
# 	Processing paper chunk 2f509202b5006d75a50efec01a8dcac19efb3af6-abstract-chunk0000
# Processing paper 6e05c0ffefc15455e928c28e764b4c87c32af184
# 	Split into 4 chunks
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0000
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0001
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0002
# 	Processing paper chunk 6e05c0ffefc15455e928c28e764b4c87c32af184-abstract-chunk0003
# Processing paper 89fe30e830401a6432dfc790a74905b8e94f17f6
# 	Split into 1 chunks
# 	Processing paper chunk 89fe30e830401a6432dfc790a74905b8e94f17f6-abstract-chunk0000
# Processing paper 0659fc02b2366617e9db8a53a1f1c901b5dc9a1f
# 	Split into 1 chunks
# 	Processing paper chunk 0659fc02b2366617e9db8a53a1f1c901b5dc9a1f-abstract-chunk0000
# Processing paper 416dd47105305512399eb7742af78570c750eb23
# 	Split into 1 chunks
# 	Processing paper chunk 416dd47105305512399eb7742af78570c750eb23-abstract-chunk0000
# Processing paper 4c7b7b2788fa4ca992f2314f03538c34e610342d
# 	Split into 1 chunks
# 	Processing paper chunk 4c7b7b2788fa4ca992f2314f03538c34e610342d-abstract-chunk0000
# Processing paper 55efb189bc0644c187eab3ddcd55bb3fd9207048
# 	Split into 1 chunks
# 	Processing paper chunk 55efb189bc0644c187eab3ddcd55bb3fd9207048-abstract-chunk0000
# Processing paper 978e744fe77709b8efef6808b94f1231484a7062
# 	Split into 1 chunks
# 	Processing paper chunk 978e744fe77709b8efef6808b94f1231484a7062-abstract-chunk0000
# Processing paper d056025641750fe1fed25d5de87a4f565e53acca
# 	Split into 1 chunks
# 	Processing paper chunk d056025641750fe1fed25d5de87a4f565e53acca-abstract-chunk0000
# Processing paper d7ac5161a3b19098da3c2891e72a2dcb9cb8373c
# 	Split into 1 chunks
# 	Processing paper chunk d7ac5161a3b19098da3c2891e72a2dcb9cb8373c-abstract-chunk0000
# Processing paper 1804e9e32dd4eb76a32e2ba96c7899a569869236
# 	Split into 1 chunks
# 	Processing paper chunk 1804e9e32dd4eb76a32e2ba96c7899a569869236-abstract-chunk0000
# Processing paper 5cf3f12a5750e821f2f53fecbb0e6dbae01ea5f5
# 	Split into 1 chunks
# 	Processing paper chunk 5cf3f12a5750e821f2f53fecbb0e6dbae01ea5f5-abstract-chunk0000
# Processing paper ba51eaafa9d13788566c08786cd4545bf138bc56
# 	Split into 1 chunks
# 	Processing paper chunk ba51eaafa9d13788566c08786cd4545bf138bc56-abstract-chunk0000
# Processing paper be08f8846b625e5cce70d9b8df6c092d2d37e789
# 	Split into 2 chunks
# 	Processing paper chunk be08f8846b625e5cce70d9b8df6c092d2d37e789-abstract-chunk0000
# 	Processing paper chunk be08f8846b625e5cce70d9b8df6c092d2d37e789-abstract-chunk0001
# Processing paper f37bd611a0fccf1288350529b673a84a4832cd83
# 	Split into 1 chunks
# 	Processing paper chunk f37bd611a0fccf1288350529b673a84a4832cd83-abstract-chunk0000
# Processing paper 00aa3398b80b1611c825523e578028cff32d765f
# 	Split into 1 chunks
# 	Processing paper chunk 00aa3398b80b1611c825523e578028cff32d765f-abstract-chunk0000
# Processing paper 05b090ecac784673c37ea9cd890d1eaa46354095
# 	Split into 1 chunks
# 	Processing paper chunk 05b090ecac784673c37ea9cd890d1eaa46354095-abstract-chunk0000
# Processing paper 7e440765d8971816c7f3cb88a3f74774cea452b0
# 	Split into 1 chunks
# 	Processing paper chunk 7e440765d8971816c7f3cb88a3f74774cea452b0-abstract-chunk0000
# Processing paper 917e25aa1d063b415c890b7d8d49d270e2efef1b
# 	Split into 1 chunks
# 	Processing paper chunk 917e25aa1d063b415c890b7d8d49d270e2efef1b-abstract-chunk0000
# Processing paper 99c2a83f130d0630ebd1f9a66e690dfaac9b49a3
# 	Split into 1 chunks
# 	Processing paper chunk 99c2a83f130d0630ebd1f9a66e690dfaac9b49a3-abstract-chunk0000
# Processing paper fc52fb6998be08bbf197708b6aa7dd2c183d5bc1
# 	Split into 1 chunks
# 	Processing paper chunk fc52fb6998be08bbf197708b6aa7dd2c183d5bc1-abstract-chunk0000
# Processing paper 0c9fc58a2236d4540fb523c8e9470744594ce8ba
# 	Split into 1 chunks
# 	Processing paper chunk 0c9fc58a2236d4540fb523c8e9470744594ce8ba-abstract-chunk0000
# Processing paper 1fda875a07ef976b2c1b212c63de99fb3a36fe80
# 	Split into 1 chunks
# 	Processing paper chunk 1fda875a07ef976b2c1b212c63de99fb3a36fe80-abstract-chunk0000
# Processing paper 417b6fdc34fa853ea474a88ee81a27df8a1ddb6b
# 	Split into 1 chunks
# 	Processing paper chunk 417b6fdc34fa853ea474a88ee81a27df8a1ddb6b-abstract-chunk0000
# Processing paper 19de1eed6795cd7c65803df79c2279ade1bf403b
# 	Split into 1 chunks
# 	Processing paper chunk 19de1eed6795cd7c65803df79c2279ade1bf403b-abstract-chunk0000
# Processing paper 57ec18cb08c8d9da143d0939dbfed87bcb22a4d2
# 	Split into 1 chunks
# 	Processing paper chunk 57ec18cb08c8d9da143d0939dbfed87bcb22a4d2-abstract-chunk0000
# Processing paper b2f3ae50b598514e1a892256a689feb8b699d9c7
# 	Split into 1 chunks
# 	Processing paper chunk b2f3ae50b598514e1a892256a689feb8b699d9c7-abstract-chunk0000
# Processing paper d4827844a66bc05d103de604ec535b1df5dfe17d
# 	Split into 1 chunks
# 	Processing paper chunk d4827844a66bc05d103de604ec535b1df5dfe17d-abstract-chunk0000
# Processing paper d7d2096c52cb3d0e1ce6c4b749fe0bc1ddef4953
# 	Split into 1 chunks
# 	Processing paper chunk d7d2096c52cb3d0e1ce6c4b749fe0bc1ddef4953-abstract-chunk0000
# Processing paper db27d94baae6809abaea58ff39efb79f08477df6
# 	Split into 1 chunks
# 	Processing paper chunk db27d94baae6809abaea58ff39efb79f08477df6-abstract-chunk0000
# Processing paper e47a24e897419acbf49907958ef47e573e804a02
# 	Split into 1 chunks
# 	Processing paper chunk e47a24e897419acbf49907958ef47e573e804a02-abstract-chunk0000
# Processing paper 314cc25cd5aa73cd71ff5e8165015366cbe52310
# 	Split into 2 chunks
# 	Processing paper chunk 314cc25cd5aa73cd71ff5e8165015366cbe52310-abstract-chunk0000
# 	Processing paper chunk 314cc25cd5aa73cd71ff5e8165015366cbe52310-abstract-chunk0001
# Processing paper 936da812e62f14151ec5980c0650dd677de28a8a
# 	Split into 1 chunks
# 	Processing paper chunk 936da812e62f14151ec5980c0650dd677de28a8a-abstract-chunk0000
# Processing paper b73fb06516e3d9026c48c5b458cb9c5ee9a48335
# 	Split into 1 chunks
# 	Processing paper chunk b73fb06516e3d9026c48c5b458cb9c5ee9a48335-abstract-chunk0000
# Processing paper 388cbca4fa7db0b926a95463f42825f3d5c83845
# 	Split into 1 chunks
# 	Processing paper chunk 388cbca4fa7db0b926a95463f42825f3d5c83845-abstract-chunk0000
# Processing paper 6099fa73b93f0ad1782e8d698c82c08340ba9975
# 	Split into 1 chunks
# 	Processing paper chunk 6099fa73b93f0ad1782e8d698c82c08340ba9975-abstract-chunk0000
# Processing paper b3c6afd425c12ed11fb8995f83d146fc6a5c3d05
# 	Split into 1 chunks
# 	Processing paper chunk b3c6afd425c12ed11fb8995f83d146fc6a5c3d05-abstract-chunk0000
# Processing paper 029d5712d72c4db1c92465aee76a23172cdd43d6
# 	Split into 1 chunks
# 	Processing paper chunk 029d5712d72c4db1c92465aee76a23172cdd43d6-abstract-chunk0000
# Processing paper 322597d75dc8b89bf09dd6cf2614f08f12dadb35
# 	Split into 1 chunks
# 	Processing paper chunk 322597d75dc8b89bf09dd6cf2614f08f12dadb35-abstract-chunk0000
# Processing paper 3d87776824a87007a16644e1c6970768d9fcfd73
# 	Split into 1 chunks
# 	Processing paper chunk 3d87776824a87007a16644e1c6970768d9fcfd73-abstract-chunk0000
# Processing paper 48e191de1cdd03f07854c29f9963ad2515e60a6a
# 	Split into 1 chunks
# 	Processing paper chunk 48e191de1cdd03f07854c29f9963ad2515e60a6a-abstract-chunk0000
# Processing paper 8aeeedae90d5ce75ee5c51f815fb9305e25d37ba
# 	Split into 1 chunks
# 	Processing paper chunk 8aeeedae90d5ce75ee5c51f815fb9305e25d37ba-abstract-chunk0000
# Processing paper 9bf809b7727c0e9f80021657049edae4a8e71e84
# 	Split into 1 chunks
# 	Processing paper chunk 9bf809b7727c0e9f80021657049edae4a8e71e84-abstract-chunk0000
# Processing paper b6235fb2df343b4b3b3bbf443ccc1b62210f9967
# 	Split into 1 chunks
# 	Processing paper chunk b6235fb2df343b4b3b3bbf443ccc1b62210f9967-abstract-chunk0000
# Processing paper ffe9f6f08165fa0add71d599ea30c6a4291f7eb3
# 	Split into 1 chunks
# 	Processing paper chunk ffe9f6f08165fa0add71d599ea30c6a4291f7eb3-abstract-chunk0000
# Processing paper 0283f01f612ab4e403691765db2da6b2cd729a4d
# 	Split into 1 chunks
# 	Processing paper chunk 0283f01f612ab4e403691765db2da6b2cd729a4d-abstract-chunk0000
# Processing paper 10687584677c3bcfb0cfaadf240c9eff3257ba96
# 	Split into 1 chunks
# 	Processing paper chunk 10687584677c3bcfb0cfaadf240c9eff3257ba96-abstract-chunk0000
# Processing paper 9f482f1f5c604095a4730d05cc99f291fe8ee946
# 	Split into 1 chunks
# 	Processing paper chunk 9f482f1f5c604095a4730d05cc99f291fe8ee946-abstract-chunk0000
# Processing paper a8390849e288da56836fd6c002c3055ef5673f5b
# 	Split into 2 chunks
# 	Processing paper chunk a8390849e288da56836fd6c002c3055ef5673f5b-abstract-chunk0000
# 	Processing paper chunk a8390849e288da56836fd6c002c3055ef5673f5b-abstract-chunk0001
# Processing paper f7b3a2cd1de40e6c7798b8b6cbf430641e0a9287
# 	Split into 1 chunks
# 	Processing paper chunk f7b3a2cd1de40e6c7798b8b6cbf430641e0a9287-abstract-chunk0000
# Processing paper 3bd1f794875ea11b90f2d7f5faccf1b9e37828d0
# 	Split into 1 chunks
# 	Processing paper chunk 3bd1f794875ea11b90f2d7f5faccf1b9e37828d0-abstract-chunk0000
# Processing paper 41159220bf4ef527f8d5ac9935fbaa8f2bc30d95
# 	Split into 2 chunks
# 	Processing paper chunk 41159220bf4ef527f8d5ac9935fbaa8f2bc30d95-abstract-chunk0000
# 	Processing paper chunk 41159220bf4ef527f8d5ac9935fbaa8f2bc30d95-abstract-chunk0001
# Processing paper 6dc7aa3ea4b4c57da2a6a66454b6ab18a2fe3d37
# 	Split into 1 chunks
# 	Processing paper chunk 6dc7aa3ea4b4c57da2a6a66454b6ab18a2fe3d37-abstract-chunk0000
# Processing paper 659ab3d3030939e2d3b248b2db8bcc626192ac7a
# 	Split into 1 chunks
# 	Processing paper chunk 659ab3d3030939e2d3b248b2db8bcc626192ac7a-abstract-chunk0000
# Processing paper 7663998b03ef7e3ebd864fe5035564cdfd834bf2
# 	Split into 1 chunks
# 	Processing paper chunk 7663998b03ef7e3ebd864fe5035564cdfd834bf2-abstract-chunk0000
# Processing paper 24bc16fa1e97a35e9ea58c1c1456d20e84276079
# 	Split into 1 chunks
# 	Processing paper chunk 24bc16fa1e97a35e9ea58c1c1456d20e84276079-abstract-chunk0000
# Processing paper 8030bf667987ff5d9dd169067b0fec851d1f3b8f
# 	Split into 1 chunks
# 	Processing paper chunk 8030bf667987ff5d9dd169067b0fec851d1f3b8f-abstract-chunk0000
# Processing paper 9bd005e0a0494ca0a67ede02fd7e0ecb71681b90
# 	Split into 1 chunks
# 	Processing paper chunk 9bd005e0a0494ca0a67ede02fd7e0ecb71681b90-abstract-chunk0000
# Processing paper ad4a47be28f43a5dd52a30d4c4e6f4acce3ad9ce
# 	Split into 1 chunks
# 	Processing paper chunk ad4a47be28f43a5dd52a30d4c4e6f4acce3ad9ce-abstract-chunk0000
# Processing paper d0b1a8f061a7af536fb33dab3720a52ecf70a0c5
# 	Split into 1 chunks
# 	Processing paper chunk d0b1a8f061a7af536fb33dab3720a52ecf70a0c5-abstract-chunk0000
# Processing paper f05b35a00d779a9dbfdda8ad4a7efd8bc61f547f
# 	Split into 1 chunks
# 	Processing paper chunk f05b35a00d779a9dbfdda8ad4a7efd8bc61f547f-abstract-chunk0000
# Processing paper 261dbbef697eb434df811f3bb177710753a44870
# 	Split into 1 chunks
# 	Processing paper chunk 261dbbef697eb434df811f3bb177710753a44870-abstract-chunk0000
# Processing paper 8ed593a15492060d64fd7344745d84916bfb4875
# 	Split into 1 chunks
# 	Processing paper chunk 8ed593a15492060d64fd7344745d84916bfb4875-abstract-chunk0000
# Processing paper 9314a908d0fee5f12c9bc46850429d9eefb2dfc0
# 	Split into 1 chunks
# 	Processing paper chunk 9314a908d0fee5f12c9bc46850429d9eefb2dfc0-abstract-chunk0000
# Processing paper a4fd2b6f1c96f4ec19461d473f0435aeea6f4716
# 	Split into 1 chunks
# 	Processing paper chunk a4fd2b6f1c96f4ec19461d473f0435aeea6f4716-abstract-chunk0000
# Processing paper cd79fb9c1d3c6321e76bfb876e47506cd95b1af6
# 	Split into 2 chunks
# 	Processing paper chunk cd79fb9c1d3c6321e76bfb876e47506cd95b1af6-abstract-chunk0000
# 	Processing paper chunk cd79fb9c1d3c6321e76bfb876e47506cd95b1af6-abstract-chunk0001
# Processing paper d0d4929b9f23e3e1faf0786bad6c3baf7be82b69
# 	Split into 1 chunks
# 	Processing paper chunk d0d4929b9f23e3e1faf0786bad6c3baf7be82b69-abstract-chunk0000
# Processing paper 02fe361570c60dc29414e6019f6942a5135813e3
# 	Split into 1 chunks
# 	Processing paper chunk 02fe361570c60dc29414e6019f6942a5135813e3-abstract-chunk0000
# Processing paper 241c857d0258cc213e35d6ac4fa2fdf1e941ef39
# 	Split into 1 chunks
# 	Processing paper chunk 241c857d0258cc213e35d6ac4fa2fdf1e941ef39-abstract-chunk0000
# Processing paper 4a90d90405f92268529bdde512c538d2c7f175cb
# 	Split into 2 chunks
# 	Processing paper chunk 4a90d90405f92268529bdde512c538d2c7f175cb-abstract-chunk0000
# 	Processing paper chunk 4a90d90405f92268529bdde512c538d2c7f175cb-abstract-chunk0001
# Processing paper 7f7d8adbaeca1903181dbcceb453b7c4155cb0ed
# 	Split into 1 chunks
# 	Processing paper chunk 7f7d8adbaeca1903181dbcceb453b7c4155cb0ed-abstract-chunk0000
# Processing paper 8b721421d4a8e63bb060ea99f73534a0feba506e
# 	Split into 2 chunks
# 	Processing paper chunk 8b721421d4a8e63bb060ea99f73534a0feba506e-abstract-chunk0000
# 	Processing paper chunk 8b721421d4a8e63bb060ea99f73534a0feba506e-abstract-chunk0001
# Processing paper a082b150d6cf0b2596c260a5fc9408d8ccfb7be4
# 	Split into 1 chunks
# 	Processing paper chunk a082b150d6cf0b2596c260a5fc9408d8ccfb7be4-abstract-chunk0000
# Processing paper d6ba86db03a31e753c744fcaa6d895d7919d8d56
# 	Split into 2 chunks
# 	Processing paper chunk d6ba86db03a31e753c744fcaa6d895d7919d8d56-abstract-chunk0000
# 	Processing paper chunk d6ba86db03a31e753c744fcaa6d895d7919d8d56-abstract-chunk0001
# Processing paper e2eefd77d69f3fb7da82cabf76ce43f64fe53db6
# 	Split into 1 chunks
# 	Processing paper chunk e2eefd77d69f3fb7da82cabf76ce43f64fe53db6-abstract-chunk0000
# Processing paper 1a85002c52c31f50c7c2a950d307546dc1f8f111
# 	Split into 1 chunks
# 	Processing paper chunk 1a85002c52c31f50c7c2a950d307546dc1f8f111-abstract-chunk0000
# Processing paper 2de9cb3e31780104cae60471759596294bc8ba2a
# 	Split into 1 chunks
# 	Processing paper chunk 2de9cb3e31780104cae60471759596294bc8ba2a-abstract-chunk0000
# Processing paper 9a700d42161ae4b8acfdde297645b1d93986c56b
# 	Split into 1 chunks
# 	Processing paper chunk 9a700d42161ae4b8acfdde297645b1d93986c56b-abstract-chunk0000
# Processing paper a1f573febb87c9288a087445536d55cf5a106b0d
# 	Split into 1 chunks
# 	Processing paper chunk a1f573febb87c9288a087445536d55cf5a106b0d-abstract-chunk0000
# Processing paper a79a6da7579348cd5b4ed230d9ef3367c1d3f2e0
# 	Split into 2 chunks
# 	Processing paper chunk a79a6da7579348cd5b4ed230d9ef3367c1d3f2e0-abstract-chunk0000
# 	Processing paper chunk a79a6da7579348cd5b4ed230d9ef3367c1d3f2e0-abstract-chunk0001
# Processing paper ae566412f2eef35010605079e734a208e6c72264
# 	Split into 1 chunks
# 	Processing paper chunk ae566412f2eef35010605079e734a208e6c72264-abstract-chunk0000
# Processing paper b415ce9d80ff474b6a88f0b8fae2edd6b326d793
# 	Split into 1 chunks
# 	Processing paper chunk b415ce9d80ff474b6a88f0b8fae2edd6b326d793-abstract-chunk0000
# Processing paper b9a77adb11e2deb9790e3ea144b9ea55579f8cea
# 	Split into 1 chunks
# 	Processing paper chunk b9a77adb11e2deb9790e3ea144b9ea55579f8cea-abstract-chunk0000
# Processing paper ead83466deb581f75fe61733d6632bd3bdace899
# 	Split into 2 chunks
# 	Processing paper chunk ead83466deb581f75fe61733d6632bd3bdace899-abstract-chunk0000
# 	Processing paper chunk ead83466deb581f75fe61733d6632bd3bdace899-abstract-chunk0001
# Processing paper 1e29029b56defd31810986419272de563b88b507
# 	Split into 1 chunks
# 	Processing paper chunk 1e29029b56defd31810986419272de563b88b507-abstract-chunk0000
# Processing paper 2a901cfdc333c5804b74710f6b72b4483f1a84e7
# 	Split into 1 chunks
# 	Processing paper chunk 2a901cfdc333c5804b74710f6b72b4483f1a84e7-abstract-chunk0000
# Processing paper 3c7351fae8f4ab424612135cb23f4c87aafa1c43
# 	Split into 1 chunks
# 	Processing paper chunk 3c7351fae8f4ab424612135cb23f4c87aafa1c43-abstract-chunk0000
# Processing paper 64130afacdd708da5e1a9241836154a82c17ee1c
# 	Split into 1 chunks
# 	Processing paper chunk 64130afacdd708da5e1a9241836154a82c17ee1c-abstract-chunk0000
# Processing paper c3165d9635d0303607a1e49faa953f2ae8a42cc5
# 	Split into 1 chunks
# 	Processing paper chunk c3165d9635d0303607a1e49faa953f2ae8a42cc5-abstract-chunk0000
# Processing paper f41a85f621f6b35a86161d2171627affc0779f45
# 	Split into 2 chunks
# 	Processing paper chunk f41a85f621f6b35a86161d2171627affc0779f45-abstract-chunk0000
# 	Processing paper chunk f41a85f621f6b35a86161d2171627affc0779f45-abstract-chunk0001
# Processing paper 32e6ef0bc4c57df54536224889a942386b346d64
# 	Split into 1 chunks
# 	Processing paper chunk 32e6ef0bc4c57df54536224889a942386b346d64-abstract-chunk0000
# Processing paper 443d7d56ffba5bff5d9730215bcd3526d78844c0
# 	Split into 1 chunks
# 	Processing paper chunk 443d7d56ffba5bff5d9730215bcd3526d78844c0-abstract-chunk0000
# Processing paper f20bb44802b39fdfef9976d200eb79b363dba4bc
# 	Split into 1 chunks
# 	Processing paper chunk f20bb44802b39fdfef9976d200eb79b363dba4bc-abstract-chunk0000
# Processing paper 09f332f86e2f7221dfa0c8dbcebe41ce9e6b29bb
# 	Split into 1 chunks
# 	Processing paper chunk 09f332f86e2f7221dfa0c8dbcebe41ce9e6b29bb-abstract-chunk0000
# Processing paper 67fd95777e848c38b70b0347b647f337955578b6
# 	Split into 1 chunks
# 	Processing paper chunk 67fd95777e848c38b70b0347b647f337955578b6-abstract-chunk0000
# Processing paper c79b04c6cb12404a67c43acef7b92722c5d24de0
# 	Split into 1 chunks
# 	Processing paper chunk c79b04c6cb12404a67c43acef7b92722c5d24de0-abstract-chunk0000
# Processing paper ea8e2971c8ac7f416b669c0945d71092e518cf48
# 	Split into 1 chunks
# 	Processing paper chunk ea8e2971c8ac7f416b669c0945d71092e518cf48-abstract-chunk0000
# Processing paper f862ff755bbfc786f3a98a5bbce17f8caba2712d
# 	Split into 1 chunks
# 	Processing paper chunk f862ff755bbfc786f3a98a5bbce17f8caba2712d-abstract-chunk0000
# Processing paper f9e552681947a80967727b7a71c4d6d2cfec9af7
# 	Split into 1 chunks
# 	Processing paper chunk f9e552681947a80967727b7a71c4d6d2cfec9af7-abstract-chunk0000
# Processing paper 26e748f4d942288a5fba2817ca5ed1850d10d146
# 	Split into 1 chunks
# 	Processing paper chunk 26e748f4d942288a5fba2817ca5ed1850d10d146-abstract-chunk0000
# Processing paper 3a6104a381976e24b0752ca65e87a17ff06cd589
# 	Split into 1 chunks
# 	Processing paper chunk 3a6104a381976e24b0752ca65e87a17ff06cd589-abstract-chunk0000
# Processing paper 3f95399640a364cb0289f8c4d00915701a41a2b4
# 	Split into 1 chunks
# 	Processing paper chunk 3f95399640a364cb0289f8c4d00915701a41a2b4-abstract-chunk0000
# Processing paper f0b370fed5c25d97dc1b02a38e457cdd1f5b5da0
# 	Split into 1 chunks
# 	Processing paper chunk f0b370fed5c25d97dc1b02a38e457cdd1f5b5da0-abstract-chunk0000
# Processing paper 255af007e2b36096ade73e9069b2c95fd81f5412
# 	Split into 1 chunks
# 	Processing paper chunk 255af007e2b36096ade73e9069b2c95fd81f5412-abstract-chunk0000
# Processing paper 7006dbf612103c9c34c32adb9875aac866705df4
# 	Split into 1 chunks
# 	Processing paper chunk 7006dbf612103c9c34c32adb9875aac866705df4-abstract-chunk0000
# Processing paper 9a5bfd4ebad6d04df5bc33a8db33b5187242ef24
# 	Split into 1 chunks
# 	Processing paper chunk 9a5bfd4ebad6d04df5bc33a8db33b5187242ef24-abstract-chunk0000
# Processing paper a97b1359d2b453a9179dadb4cb9a81d5e0948b9b
# 	Split into 1 chunks
# 	Processing paper chunk a97b1359d2b453a9179dadb4cb9a81d5e0948b9b-abstract-chunk0000
# Processing paper 13dbc08bb81638f51e1f14f8d6cb2f791fc762f1
# 	Split into 1 chunks
# 	Processing paper chunk 13dbc08bb81638f51e1f14f8d6cb2f791fc762f1-abstract-chunk0000
# Processing paper 0ffbee27d652a4e4e1b3c757b8c06bb831baad6c
# 	Split into 1 chunks
# 	Processing paper chunk 0ffbee27d652a4e4e1b3c757b8c06bb831baad6c-abstract-chunk0000
# Processing paper 0d040a65ee44007cf77f2df69a1c3b0a27f54efa
# 	Split into 1 chunks
# 	Processing paper chunk 0d040a65ee44007cf77f2df69a1c3b0a27f54efa-abstract-chunk0000
# Processing paper 13bc9e5ab967709599219765dcda72faf2275a0e
# 	Split into 1 chunks
# 	Processing paper chunk 13bc9e5ab967709599219765dcda72faf2275a0e-abstract-chunk0000
# Processing paper 116090284de01bee8a801228ebc391e52cf95229
# 	Split into 1 chunks
# 	Processing paper chunk 116090284de01bee8a801228ebc391e52cf95229-abstract-chunk0000
# Processing paper 1c7d0994f55705facb1cd46ef14bb54ce692ca54
# 	Split into 1 chunks
# 	Processing paper chunk 1c7d0994f55705facb1cd46ef14bb54ce692ca54-abstract-chunk0000
# Processing paper 1d7808b3f1247083fd1c8f5fc4a02f656ecf2e33
# 	Split into 1 chunks
# 	Processing paper chunk 1d7808b3f1247083fd1c8f5fc4a02f656ecf2e33-abstract-chunk0000
# Processing paper 1e3d8cdd49539d09c8a565da7c68a412f33cbafc
# 	Split into 1 chunks
# 	Processing paper chunk 1e3d8cdd49539d09c8a565da7c68a412f33cbafc-abstract-chunk0000
# Processing paper 24af85e5e3732e54c0bc83338bfa9d84a71418a9
# 	Split into 1 chunks
# 	Processing paper chunk 24af85e5e3732e54c0bc83338bfa9d84a71418a9-abstract-chunk0000
# Processing paper 2f1ec3f641f23ed34e0ae350cb422ac27e8fd933
# 	Split into 1 chunks
# 	Processing paper chunk 2f1ec3f641f23ed34e0ae350cb422ac27e8fd933-abstract-chunk0000
# Processing paper 342755fa45061b0d1e85910cdff7292b9f939501
# 	Split into 1 chunks
# 	Processing paper chunk 342755fa45061b0d1e85910cdff7292b9f939501-abstract-chunk0000
# Processing paper 34ba1abcca832f0424bbbcb91b5e2645637a43bf
# 	Split into 1 chunks
# 	Processing paper chunk 34ba1abcca832f0424bbbcb91b5e2645637a43bf-abstract-chunk0000
# Processing paper 46916efab0489a6958d5c21a551d3c47676f5bbf
# 	Split into 1 chunks
# 	Processing paper chunk 46916efab0489a6958d5c21a551d3c47676f5bbf-abstract-chunk0000
# Processing paper 5292596f74d263ee2dce2c933beda1c6f77dedbe
# 	Split into 1 chunks
# 	Processing paper chunk 5292596f74d263ee2dce2c933beda1c6f77dedbe-abstract-chunk0000
# Processing paper 8692048a10a4c76c1e75008e56a65e7671f078c3
# 	Split into 1 chunks
# 	Processing paper chunk 8692048a10a4c76c1e75008e56a65e7671f078c3-abstract-chunk0000
# Processing paper 91a7411bff96b110c3084836304acd15002f9481
# 	Split into 1 chunks
# 	Processing paper chunk 91a7411bff96b110c3084836304acd15002f9481-abstract-chunk0000
# Processing paper 9a0d46a442087a91f6d6db1da2f7d30652ed953e
# 	Split into 1 chunks
# 	Processing paper chunk 9a0d46a442087a91f6d6db1da2f7d30652ed953e-abstract-chunk0000
# Processing paper 9d1364c6e8b30f80735fc79156200833725f337c
# 	Split into 1 chunks
# 	Processing paper chunk 9d1364c6e8b30f80735fc79156200833725f337c-abstract-chunk0000
# Processing paper a9a0c7dcd19d9ce06f3c2a89a83a0b29c0d8f537
# 	Split into 1 chunks
# 	Processing paper chunk a9a0c7dcd19d9ce06f3c2a89a83a0b29c0d8f537-abstract-chunk0000
# Processing paper acdeb62749efe973512a8cee91750e14969126e3
# 	Split into 1 chunks
# 	Processing paper chunk acdeb62749efe973512a8cee91750e14969126e3-abstract-chunk0000
# Processing paper c20e8b3a9734f639c4e5aee42319e97331339e2b
# 	Split into 1 chunks
# 	Processing paper chunk c20e8b3a9734f639c4e5aee42319e97331339e2b-abstract-chunk0000
# Processing paper c46db22a03406a765ffce2af1f55af7ce29e6070
# 	Split into 1 chunks
# 	Processing paper chunk c46db22a03406a765ffce2af1f55af7ce29e6070-abstract-chunk0000
# Processing paper c83b45b57b37b63f724b91aa890bcf74f24a8936
# 	Split into 1 chunks
# 	Processing paper chunk c83b45b57b37b63f724b91aa890bcf74f24a8936-abstract-chunk0000
# Processing paper e35e4a9f9764599503bca02c45786f1a2c76610d
# 	Split into 1 chunks
# 	Processing paper chunk e35e4a9f9764599503bca02c45786f1a2c76610d-abstract-chunk0000
# Processing paper e39d921a84e146b4b3cb8abba5c889cc34362e26
# 	Split into 1 chunks
# 	Processing paper chunk e39d921a84e146b4b3cb8abba5c889cc34362e26-abstract-chunk0000
# Processing paper eecd28eee7e4162b5cf26fe9ccce610abe4c8b1c
# 	Split into 1 chunks
# 	Processing paper chunk eecd28eee7e4162b5cf26fe9ccce610abe4c8b1c-abstract-chunk0000
# Processing paper f224c4a581c94ce771b23b780db251bb89a58a74
# 	Split into 1 chunks
# 	Processing paper chunk f224c4a581c94ce771b23b780db251bb89a58a74-abstract-chunk0000
# Processing paper f44c4519aa20598d0cf2a8078c3fbc78af09a9c5
# 	Split into 1 chunks
# 	Processing paper chunk f44c4519aa20598d0cf2a8078c3fbc78af09a9c5-abstract-chunk0000
# Processing paper f6b46b9d4d6261e4350c1a6e93f15218d5df73e3
# 	Split into 1 chunks
# 	Processing paper chunk f6b46b9d4d6261e4350c1a6e93f15218d5df73e3-abstract-chunk0000
# Processing paper f78fef46ef0a90d4934cb0366aa28bbb6996c809
# 	Split into 1 chunks
# 	Processing paper chunk f78fef46ef0a90d4934cb0366aa28bbb6996c809-abstract-chunk0000
# Processing paper 312cb3eab41c14ff1c232e9ed8785ee1a0490e0d
# 	Split into 1 chunks
# 	Processing paper chunk 312cb3eab41c14ff1c232e9ed8785ee1a0490e0d-abstract-chunk0000
# Processing paper 554fff95be0c4edba6870ce8621c7ccb35587f13
# 	Split into 1 chunks
# 	Processing paper chunk 554fff95be0c4edba6870ce8621c7ccb35587f13-abstract-chunk0000
# Processing paper 992b4fbf67db1965be791974c580ceb5a356f0b3
# 	Split into 1 chunks
# 	Processing paper chunk 992b4fbf67db1965be791974c580ceb5a356f0b3-abstract-chunk0000
# Processing paper bc36061fb7b77af754f0a27a8bb7e01bb1546d04
# 	Split into 1 chunks
# 	Processing paper chunk bc36061fb7b77af754f0a27a8bb7e01bb1546d04-abstract-chunk0000
# Processing paper c8d38f7aac70b108f4d0c04129d91b6e58b109ba
# 	Split into 1 chunks
# 	Processing paper chunk c8d38f7aac70b108f4d0c04129d91b6e58b109ba-abstract-chunk0000
# Processing paper bd996a9baada4e82290236e3985f979a27b55dc2
# 	Split into 1 chunks
# 	Processing paper chunk bd996a9baada4e82290236e3985f979a27b55dc2-abstract-chunk0000
# Processing paper c98929ab690a6c29d3402d4472e09770e1e89281
# 	Split into 1 chunks
# 	Processing paper chunk c98929ab690a6c29d3402d4472e09770e1e89281-abstract-chunk0000
# Processing paper d3bebfe3d7df045ed31031a37ee7319f218e583b
# 	Split into 1 chunks
# 	Processing paper chunk d3bebfe3d7df045ed31031a37ee7319f218e583b-abstract-chunk0000
# Processing paper 1a561f94de1d01bd9fef53c949a48e1e902985f0
# 	Split into 1 chunks
# 	Processing paper chunk 1a561f94de1d01bd9fef53c949a48e1e902985f0-abstract-chunk0000
# Processing paper 2aaf01e5831fb4b8577e38005fa66bf761e15b32
# 	Split into 1 chunks
# 	Processing paper chunk 2aaf01e5831fb4b8577e38005fa66bf761e15b32-abstract-chunk0000
# Processing paper 5b2880b492a0120fa73ea6990bd3cffa376e090f
# 	Split into 1 chunks
# 	Processing paper chunk 5b2880b492a0120fa73ea6990bd3cffa376e090f-abstract-chunk0000
# Processing paper 8a3a72e1244cd59ca4506206b5514ab31a520c1e
# 	Split into 1 chunks
# 	Processing paper chunk 8a3a72e1244cd59ca4506206b5514ab31a520c1e-abstract-chunk0000
# Processing paper b4786ad9cdbd690c97e69d2df95967fba1ae3adf
# 	Split into 1 chunks
# 	Processing paper chunk b4786ad9cdbd690c97e69d2df95967fba1ae3adf-abstract-chunk0000
# Processing paper ff72fde8819c5661228f9380050f6855a061e877
# 	Split into 1 chunks
# 	Processing paper chunk ff72fde8819c5661228f9380050f6855a061e877-abstract-chunk0000
# Processing paper 000cf8c93b9f3405a6e9249a59f71ae0fde11e06
# 	Split into 1 chunks
# 	Processing paper chunk 000cf8c93b9f3405a6e9249a59f71ae0fde11e06-abstract-chunk0000
# Processing paper 05a1be7a59445c35e172d8624edac25ba6fba7d1
# 	Split into 1 chunks
# 	Processing paper chunk 05a1be7a59445c35e172d8624edac25ba6fba7d1-abstract-chunk0000
# Processing paper 1600795f82aa10dc63d63dc4c24eb1b6ba10e34e
# 	Split into 1 chunks
# 	Processing paper chunk 1600795f82aa10dc63d63dc4c24eb1b6ba10e34e-abstract-chunk0000
# Processing paper 18146fab686834163417fb6c1da5da205c2edb68
# 	Split into 1 chunks
# 	Processing paper chunk 18146fab686834163417fb6c1da5da205c2edb68-abstract-chunk0000
# Processing paper 114f94215549bf6ee3ddf8ec91e728fc923f849b
# 	Split into 1 chunks
# 	Processing paper chunk 114f94215549bf6ee3ddf8ec91e728fc923f849b-abstract-chunk0000
# Processing paper 23dbe0abc08115ccfffa3d1db4c6c4c877aa518b
# 	Split into 1 chunks
# 	Processing paper chunk 23dbe0abc08115ccfffa3d1db4c6c4c877aa518b-abstract-chunk0000
# Processing paper 37347f2c04a07dc3dca4ec615f34a4cea63ea4d1
# 	Split into 1 chunks
# 	Processing paper chunk 37347f2c04a07dc3dca4ec615f34a4cea63ea4d1-abstract-chunk0000
# Processing paper 7f077cf6c76a8574ec2005b157b867655569a163
# 	Split into 1 chunks
# 	Processing paper chunk 7f077cf6c76a8574ec2005b157b867655569a163-abstract-chunk0000
# Processing paper b32338c44713b7c78fe114991616ed00e97da20c
# 	Split into 1 chunks
# 	Processing paper chunk b32338c44713b7c78fe114991616ed00e97da20c-abstract-chunk0000
# Processing paper bbc471f0c27fed5cdee35b2f962c5a6b1dc6f92c
# 	Split into 1 chunks
# 	Processing paper chunk bbc471f0c27fed5cdee35b2f962c5a6b1dc6f92c-abstract-chunk0000
# Processing paper c383cff48b89e71e310d71450dc2335e8e93aae8
# 	Split into 1 chunks
# 	Processing paper chunk c383cff48b89e71e310d71450dc2335e8e93aae8-abstract-chunk0000
# Processing paper e7562c7c55b25684e869a06c8dbeaafe46ed43c9
# 	Split into 1 chunks
# 	Processing paper chunk e7562c7c55b25684e869a06c8dbeaafe46ed43c9-abstract-chunk0000
# Processing paper 25d3018be561be360ef671072978145ea73a1149
# 	Split into 1 chunks
# 	Processing paper chunk 25d3018be561be360ef671072978145ea73a1149-abstract-chunk0000
# Processing paper a3114c133cbb8d7b088afbbc0fd4b6238de8e024
# 	Split into 1 chunks
# 	Processing paper chunk a3114c133cbb8d7b088afbbc0fd4b6238de8e024-abstract-chunk0000
# Processing paper a59da0e30bcfa1d18f120e625f96fa064ed08ca2
# 	Split into 1 chunks
# 	Processing paper chunk a59da0e30bcfa1d18f120e625f96fa064ed08ca2-abstract-chunk0000
# Processing paper cc87154e1c756489c4cf95d403166d316c083f71
# 	Split into 1 chunks
# 	Processing paper chunk cc87154e1c756489c4cf95d403166d316c083f71-abstract-chunk0000
# Processing paper 081a57f6920798e1238eea9d6b91e5bec0cf03e7
# 	Split into 1 chunks
# 	Processing paper chunk 081a57f6920798e1238eea9d6b91e5bec0cf03e7-abstract-chunk0000
# Processing paper 256a2227b79dd81a7bdf5295fc5537b4f78ec1cf
# 	Split into 1 chunks
# 	Processing paper chunk 256a2227b79dd81a7bdf5295fc5537b4f78ec1cf-abstract-chunk0000
# Processing paper 27269f2e55f2923f9acc6e8769fa9a8637b632cb
# 	Split into 1 chunks
# 	Processing paper chunk 27269f2e55f2923f9acc6e8769fa9a8637b632cb-abstract-chunk0000
# Processing paper 529b1e113cb9fb0c15998ba887a2d398d92137ca
# 	Split into 1 chunks
# 	Processing paper chunk 529b1e113cb9fb0c15998ba887a2d398d92137ca-abstract-chunk0000
# Processing paper 61bb06045d7d766e991b57473664aa4c05b406e6
# 	Split into 1 chunks
# 	Processing paper chunk 61bb06045d7d766e991b57473664aa4c05b406e6-abstract-chunk0000
# Processing paper e50b36766f964555e65fd7ef62ceff6d7dc79e51
# 	Split into 1 chunks
# 	Processing paper chunk e50b36766f964555e65fd7ef62ceff6d7dc79e51-abstract-chunk0000
# Processing paper f4f5a654e9f14d4f80f0f3c9b72e3b19daaeab46
# 	Split into 1 chunks
# 	Processing paper chunk f4f5a654e9f14d4f80f0f3c9b72e3b19daaeab46-abstract-chunk0000
# Processing paper 3ed2e29069fa425d877643018988ea85ffc27e4e
# 	Split into 1 chunks
# 	Processing paper chunk 3ed2e29069fa425d877643018988ea85ffc27e4e-abstract-chunk0000
# Processing paper 54840c7ffb4a1c57e105cdd5f5bc0e830b0d8161
# 	Split into 1 chunks
# 	Processing paper chunk 54840c7ffb4a1c57e105cdd5f5bc0e830b0d8161-abstract-chunk0000
# Processing paper 6c4268f699982a3d7f9407fd2dc6cb6ad5a687f0
# 	Split into 1 chunks
# 	Processing paper chunk 6c4268f699982a3d7f9407fd2dc6cb6ad5a687f0-abstract-chunk0000
# Processing paper 7d9a5517304e989e6045bbdc6f6619d34974f618
# 	Split into 1 chunks
# 	Processing paper chunk 7d9a5517304e989e6045bbdc6f6619d34974f618-abstract-chunk0000
# Processing paper 9025e25230f9addd7b6122c478ae798300feb5b0
# 	Split into 1 chunks
# 	Processing paper chunk 9025e25230f9addd7b6122c478ae798300feb5b0-abstract-chunk0000
# Processing paper b01428e61792fa7bef6f80baf7f6d6f6e7029117
# 	Split into 1 chunks
# 	Processing paper chunk b01428e61792fa7bef6f80baf7f6d6f6e7029117-abstract-chunk0000
# Processing paper bcfa782bfd5f7949a9023d950e576d5e11dc4a3e
# 	Split into 1 chunks
# 	Processing paper chunk bcfa782bfd5f7949a9023d950e576d5e11dc4a3e-abstract-chunk0000
# Processing paper d0c195bab3c4f95c9fa5d7ce35bd35175754f682
# 	Split into 1 chunks
# 	Processing paper chunk d0c195bab3c4f95c9fa5d7ce35bd35175754f682-abstract-chunk0000
# Processing paper e5f3d49d86dc1e9867dc49643bc5f865655d4769
# 	Split into 1 chunks
# 	Processing paper chunk e5f3d49d86dc1e9867dc49643bc5f865655d4769-abstract-chunk0000
# Processing paper e87180d9606acfe6c42330a13e14f62672da1692
# 	Split into 1 chunks
# 	Processing paper chunk e87180d9606acfe6c42330a13e14f62672da1692-abstract-chunk0000
# Processing paper ec5bb0e5615da07aadd6b04ef61573865ee7f506
# 	Split into 1 chunks
# 	Processing paper chunk ec5bb0e5615da07aadd6b04ef61573865ee7f506-abstract-chunk0000
# Processing paper f5606d8c8869fd8922b489a616e64696e7112b6e
# 	Split into 1 chunks
# 	Processing paper chunk f5606d8c8869fd8922b489a616e64696e7112b6e-abstract-chunk0000
# Processing paper fdfbabbd062e6654aa5fd4c2e8d5330e7df582ff
# 	Split into 1 chunks
# 	Processing paper chunk fdfbabbd062e6654aa5fd4c2e8d5330e7df582ff-abstract-chunk0000
# Processing paper 078fdb56698738891f47a310ef31d8504cb000b0
# 	Split into 2 chunks
# 	Processing paper chunk 078fdb56698738891f47a310ef31d8504cb000b0-abstract-chunk0000
# 	Processing paper chunk 078fdb56698738891f47a310ef31d8504cb000b0-abstract-chunk0001
# Processing paper 0dc321d2c3c5ef03b07a133d77e946a9813af368
# 	Split into 1 chunks
# 	Processing paper chunk 0dc321d2c3c5ef03b07a133d77e946a9813af368-abstract-chunk0000
# Processing paper 2421fa774d81383cf4ed38e40ad786fe1c9b4fc8
# 	Split into 1 chunks
# 	Processing paper chunk 2421fa774d81383cf4ed38e40ad786fe1c9b4fc8-abstract-chunk0000
# Processing paper 2597e188b4892fbf51167eebe2b0831263751df6
# 	Split into 1 chunks
# 	Processing paper chunk 2597e188b4892fbf51167eebe2b0831263751df6-abstract-chunk0000
# Processing paper 25d041cf4ed763a5884a5e8d88d1d7686715a4b8
# 	Split into 1 chunks
# 	Processing paper chunk 25d041cf4ed763a5884a5e8d88d1d7686715a4b8-abstract-chunk0000
# Processing paper 296da1c9daf014f6dc076912b9b5935690b2dfb5
# 	Split into 1 chunks
# 	Processing paper chunk 296da1c9daf014f6dc076912b9b5935690b2dfb5-abstract-chunk0000
# Processing paper 318b7263b1372edf569e4bf040a2cd0c7df59cb2
# 	Split into 1 chunks
# 	Processing paper chunk 318b7263b1372edf569e4bf040a2cd0c7df59cb2-abstract-chunk0000
# Processing paper 5be447d5bfbbeb8cdaeb706a7a98552fe78ecffd
# 	Split into 1 chunks
# 	Processing paper chunk 5be447d5bfbbeb8cdaeb706a7a98552fe78ecffd-abstract-chunk0000
# Processing paper 5ff6704f510d65e344024fd5ad3ae249708a6e19
# 	Split into 1 chunks
# 	Processing paper chunk 5ff6704f510d65e344024fd5ad3ae249708a6e19-abstract-chunk0000
# Processing paper 711cdcb3660d4a15b60b77b1a77ed9e8a0ee45b5
# 	Split into 1 chunks
# 	Processing paper chunk 711cdcb3660d4a15b60b77b1a77ed9e8a0ee45b5-abstract-chunk0000
# Processing paper 82366503be9e469546edb75f687ed3b141298aa4
# 	Split into 1 chunks
# 	Processing paper chunk 82366503be9e469546edb75f687ed3b141298aa4-abstract-chunk0000
# Processing paper 88e1be781a3bbd215e9e12a92f69cfcb8c9535ad
# 	Split into 2 chunks
# 	Processing paper chunk 88e1be781a3bbd215e9e12a92f69cfcb8c9535ad-abstract-chunk0000
# 	Processing paper chunk 88e1be781a3bbd215e9e12a92f69cfcb8c9535ad-abstract-chunk0001
# Processing paper 899ff3d25f8ba4b217d2a143ba13edb8c324bdfb
# 	Split into 1 chunks
# 	Processing paper chunk 899ff3d25f8ba4b217d2a143ba13edb8c324bdfb-abstract-chunk0000
# Processing paper 9a95591fbd9f9959f58fcf4a1040e2ab951ff7bc
# 	Split into 1 chunks
# 	Processing paper chunk 9a95591fbd9f9959f58fcf4a1040e2ab951ff7bc-abstract-chunk0000
# Processing paper a7e7c73c94270744b8982b758ed3be882e649411
# 	Split into 1 chunks
# 	Processing paper chunk a7e7c73c94270744b8982b758ed3be882e649411-abstract-chunk0000
# Processing paper 0fabd727b39c3d1e5a9f723d50baa279d9f4dca6
# 	Split into 1 chunks
# 	Processing paper chunk 0fabd727b39c3d1e5a9f723d50baa279d9f4dca6-abstract-chunk0000
# Processing paper 188765bf17cd80990389deeaae5c317536411be9
# 	Split into 1 chunks
# 	Processing paper chunk 188765bf17cd80990389deeaae5c317536411be9-abstract-chunk0000
# Processing paper 23fe03e47bcc4acbb06d82c113de8248c696fc76
# 	Split into 1 chunks
# ...
# Processing paper 154cfbaf732785aa4f9f7919c9ab2729f64cfd72
# 	Split into 1 chunks
# 	Processing paper chunk 154cfbaf732785aa4f9f7919c9ab2729f64cfd72-abstract-chunk0000
# Processing paper 155dbc6b92dacd354e78b4827f8491edc1b67fa0
# 	Split into 1 chunks
# 	Processing paper chunk 155dbc6b92dacd354e78b4827f8491edc1b67fa0-abstract-chunk0000
# Processing paper 156043f4d1706ca5b9fa8bc7cc3970179c828d78
# 	Split into 1 chunks
# 	Processing paper chunk 156043f4d1706ca5b9fa8bc7cc3970179c828d78-abstract-chunk0000
# Processing paper 1629532604fc0d77dd9eed778d6d6e9509413a1c
# 	Split into 1 chunks
# 	Processing paper chunk 1629532604fc0d77dd9eed778d6d6e9509413a1c-abstract-chunk0000
# Processing paper 169352320f2c92045179801413ff03f63f54dc20
# 	Split into 1 chunks
# 	Processing paper chunk 169352320f2c92045179801413ff03f63f54dc20-abstract-chunk0000
# Processing paper 16ac972b543ecb4b07524b6cc02a5653b3b0b4a3
# 	Split into 1 chunks
# 	Processing paper chunk 16ac972b543ecb4b07524b6cc02a5653b3b0b4a3-abstract-chunk0000
# Processing paper 16b7af1860b78390769a0483d2dc5c76e47f3ce8
# 	Split into 1 chunks
# 	Processing paper chunk 16b7af1860b78390769a0483d2dc5c76e47f3ce8-abstract-chunk0000
# Processing paper 16c58c3e4c516c2c8df2aaa19f1aacb86b198529
# 	Split into 1 chunks
# 	Processing paper chunk 16c58c3e4c516c2c8df2aaa19f1aacb86b198529-abstract-chunk0000
# Processing paper 16ed6652c26815837054a9582be5771a66ee7e01
# 	Split into 1 chunks
# 	Processing paper chunk 16ed6652c26815837054a9582be5771a66ee7e01-abstract-chunk0000
# Processing paper 16f6887d9b07440aced9736a25472f8d244d16a5
# 	Split into 1 chunks
# 	Processing paper chunk 16f6887d9b07440aced9736a25472f8d244d16a5-abstract-chunk0000
# Processing paper 1712992a250828196b4e196989adbdacb84b2750
# 	Split into 1 chunks
# 	Processing paper chunk 1712992a250828196b4e196989adbdacb84b2750-abstract-chunk0000
# Processing paper 177daf9ea812d67d28607bbdc93bcd685e527e04
# 	Split into 1 chunks
# 	Processing paper chunk 177daf9ea812d67d28607bbdc93bcd685e527e04-abstract-chunk0000
# Processing paper 17dd2266f1f704d4817b153e645348b7fe801d36
# 	Split into 1 chunks
# 	Processing paper chunk 17dd2266f1f704d4817b153e645348b7fe801d36-abstract-chunk0000
# Processing paper 180775ff9a9cbdac2ae32a69e73435866a9dbe2f
# 	Split into 1 chunks
# 	Processing paper chunk 180775ff9a9cbdac2ae32a69e73435866a9dbe2f-abstract-chunk0000
# Processing paper 1837d0a48625a8dd4922f9a1f93128d7a28a2c90
# 	Split into 1 chunks
# 	Processing paper chunk 1837d0a48625a8dd4922f9a1f93128d7a28a2c90-abstract-chunk0000
# Processing paper 1863efb7d23246582f45dabeaba44d070545deb8
# 	Split into 1 chunks
# 	Processing paper chunk 1863efb7d23246582f45dabeaba44d070545deb8-abstract-chunk0000
# Processing paper 18793826b1618ae6961d5d141e4706c16fdfc91b
# 	Split into 1 chunks
# 	Processing paper chunk 18793826b1618ae6961d5d141e4706c16fdfc91b-abstract-chunk0000
# Processing paper 18b6e2a6b5b4362d2049f9e586ff9b45460bece3
# 	Split into 1 chunks
# 	Processing paper chunk 18b6e2a6b5b4362d2049f9e586ff9b45460bece3-abstract-chunk0000
# Processing paper 18c591119328cabeb5ecc3cea54a64af29d1fd9a
# 	Split into 1 chunks
# 	Processing paper chunk 18c591119328cabeb5ecc3cea54a64af29d1fd9a-abstract-chunk0000
# Processing paper 19a476c588ca314a07e02c07f7422ea154ec67b7
# 	Split into 1 chunks
# 	Processing paper chunk 19a476c588ca314a07e02c07f7422ea154ec67b7-abstract-chunk0000
# Processing paper 19a51d85e9a8a6d2ebb7cf82543e5f0eff8ea983
# 	Split into 1 chunks
# 	Processing paper chunk 19a51d85e9a8a6d2ebb7cf82543e5f0eff8ea983-abstract-chunk0000
# Processing paper 1a04c6e82176fa57e8ba049df044d4ed7e2704b0
# 	Split into 1 chunks
# 	Processing paper chunk 1a04c6e82176fa57e8ba049df044d4ed7e2704b0-abstract-chunk0000
# Processing paper 1b4053f0faec24e209a178072df6ff166aab99d6
# 	Split into 1 chunks
# 	Processing paper chunk 1b4053f0faec24e209a178072df6ff166aab99d6-abstract-chunk0000
# Processing paper 1a26ca476af4c828fdc0971513ea515bcaff99b1
# 	Split into 1 chunks
# 	Processing paper chunk 1a26ca476af4c828fdc0971513ea515bcaff99b1-abstract-chunk0000
# Processing paper 1b35981aa9ef908ec426355d02a298781ec0d1c8
# 	Split into 1 chunks
# 	Processing paper chunk 1b35981aa9ef908ec426355d02a298781ec0d1c8-abstract-chunk0000
# Processing paper 1b56953aabcbbb7d30e120c948641d1807f6b861
# 	Split into 1 chunks
# 	Processing paper chunk 1b56953aabcbbb7d30e120c948641d1807f6b861-abstract-chunk0000
# Processing paper 1b951ec455572d04eb4121a8664fa4b6cef91636
# 	Split into 1 chunks
# 	Processing paper chunk 1b951ec455572d04eb4121a8664fa4b6cef91636-abstract-chunk0000
# Processing paper 1bb52b06b7ba638469bfd44abf052ba31e9a23f8
# 	Split into 1 chunks
# 	Processing paper chunk 1bb52b06b7ba638469bfd44abf052ba31e9a23f8-abstract-chunk0000
# Processing paper 1bd0b48aee7548d913e16ba887c5bc5242878825
# 	Split into 1 chunks
# 	Processing paper chunk 1bd0b48aee7548d913e16ba887c5bc5242878825-abstract-chunk0000
# Processing paper 1bd8fd658d72ada72854ac761d11035939f3d2b7
# 	Split into 1 chunks
# 	Processing paper chunk 1bd8fd658d72ada72854ac761d11035939f3d2b7-abstract-chunk0000
# Processing paper 1bf2d463deef907a6eb62b3055800569a6ae899c
# 	Split into 1 chunks
# 	Processing paper chunk 1bf2d463deef907a6eb62b3055800569a6ae899c-abstract-chunk0000
# Processing paper 1bfc8ad012e50f713ccddf6b8eca662314065ca1
# 	Split into 1 chunks
# 	Processing paper chunk 1bfc8ad012e50f713ccddf6b8eca662314065ca1-abstract-chunk0000
# Processing paper 1c643da4c98e1d4e06827c3142dd6bd06eb92731
# 	Split into 1 chunks
# 	Processing paper chunk 1c643da4c98e1d4e06827c3142dd6bd06eb92731-abstract-chunk0000
# Processing paper 1c7cddeb4978284b3f5154b4e4e62059a3df1145
# 	Split into 1 chunks
# 	Processing paper chunk 1c7cddeb4978284b3f5154b4e4e62059a3df1145-abstract-chunk0000
# Processing paper 1cd0018848ef0ffe332077a995500f7d23c93187
# 	Split into 2 chunks
# 	Processing paper chunk 1cd0018848ef0ffe332077a995500f7d23c93187-abstract-chunk0000
# 	Processing paper chunk 1cd0018848ef0ffe332077a995500f7d23c93187-abstract-chunk0001
# Processing paper 1cd0e8222b4ccee995b25a0de504a36d5d471317
# 	Split into 1 chunks
# 	Processing paper chunk 1cd0e8222b4ccee995b25a0de504a36d5d471317-abstract-chunk0000
# Processing paper 1cdf5095717052f0a98687ea33f4b793ab5d884c
# 	Split into 1 chunks
# 	Processing paper chunk 1cdf5095717052f0a98687ea33f4b793ab5d884c-abstract-chunk0000
# Processing paper 1ce5ced3f023cc546a7cfad2f6aaebf50718511e
# 	Split into 1 chunks
# 	Processing paper chunk 1ce5ced3f023cc546a7cfad2f6aaebf50718511e-abstract-chunk0000
# Processing paper 1d312661ef7c79ecf9d2cdcd24e3615f4b7e1832
# 	Split into 1 chunks
# 	Processing paper chunk 1d312661ef7c79ecf9d2cdcd24e3615f4b7e1832-abstract-chunk0000
# Processing paper 1d3824b6ab73f899e1ee847c4c14e50d0bab7858
# 	Split into 1 chunks
# 	Processing paper chunk 1d3824b6ab73f899e1ee847c4c14e50d0bab7858-abstract-chunk0000
# Processing paper 1e5c9694b16c35f42d8f30f783bc4a91ceb7d937
# 	Split into 1 chunks
# 	Processing paper chunk 1e5c9694b16c35f42d8f30f783bc4a91ceb7d937-abstract-chunk0000
# Processing paper 1ebacfdc1e6e840becb164182f98ef73df34c242
# 	Split into 1 chunks
# 	Processing paper chunk 1ebacfdc1e6e840becb164182f98ef73df34c242-abstract-chunk0000
# Processing paper 1ef59b7efec6531e57e9cf465f2737cf773cb4d7
# 	Split into 1 chunks
# 	Processing paper chunk 1ef59b7efec6531e57e9cf465f2737cf773cb4d7-abstract-chunk0000
# Processing paper 1f46459aa86ae05a9265298491b30c77e3f69dbb
# 	Split into 1 chunks
# 	Processing paper chunk 1f46459aa86ae05a9265298491b30c77e3f69dbb-abstract-chunk0000
# Processing paper 1f55f21d1aee501e56d6ef5ca05a3c87bd154722
# 	Split into 1 chunks
# 	Processing paper chunk 1f55f21d1aee501e56d6ef5ca05a3c87bd154722-abstract-chunk0000
# Processing paper 1f58c11b17551f18be5143d4be51fc66a1287356
# 	Split into 1 chunks
# 	Processing paper chunk 1f58c11b17551f18be5143d4be51fc66a1287356-abstract-chunk0000
# Processing paper 1f5cfde6e99f162a6e6dba391ed986b91da49b19
# 	Split into 1 chunks
# 	Processing paper chunk 1f5cfde6e99f162a6e6dba391ed986b91da49b19-abstract-chunk0000
# Processing paper 1f7d0eeb2d360618d63ee440b3e556b797650b64
# 	Split into 1 chunks
# 	Processing paper chunk 1f7d0eeb2d360618d63ee440b3e556b797650b64-abstract-chunk0000
# Processing paper 1f9ff53df377f58136add0424f08cd9eae56c362
# 	Split into 1 chunks
# 	Processing paper chunk 1f9ff53df377f58136add0424f08cd9eae56c362-abstract-chunk0000
# Processing paper 1fab7cb2ee0ed71e9af10349c2d79f5b4b77b1a9
# 	Split into 1 chunks
# 	Processing paper chunk 1fab7cb2ee0ed71e9af10349c2d79f5b4b77b1a9-abstract-chunk0000
# Processing paper 1fc6cc694939cdd316ed8be40fd399bf709b6108
# 	Split into 1 chunks
# 	Processing paper chunk 1fc6cc694939cdd316ed8be40fd399bf709b6108-abstract-chunk0000
# Processing paper 1fe0e4498ef06eeb692abc59e7cb38855e6d80d0
# 	Split into 1 chunks
# 	Processing paper chunk 1fe0e4498ef06eeb692abc59e7cb38855e6d80d0-abstract-chunk0000
# Processing paper 201a5af0ca50f193b1d0022157685a04db6c50ad
# 	Split into 1 chunks
# 	Processing paper chunk 201a5af0ca50f193b1d0022157685a04db6c50ad-abstract-chunk0000
# Processing paper 2024f6c043cc25b6717ce7ce2f50b4af2df14018
# 	Split into 1 chunks
# 	Processing paper chunk 2024f6c043cc25b6717ce7ce2f50b4af2df14018-abstract-chunk0000
# Processing paper 204bfa0bb5ba00c9801c66334ea048cba501f47a
# 	Split into 1 chunks
# 	Processing paper chunk 204bfa0bb5ba00c9801c66334ea048cba501f47a-abstract-chunk0000
# Processing paper 207943fe865503068095e8d4dda79d16e0d02eb7
# 	Split into 1 chunks
# 	Processing paper chunk 207943fe865503068095e8d4dda79d16e0d02eb7-abstract-chunk0000
# Processing paper 20ac767e1d3eb0035428fefe3ea83095a5e281db
# 	Split into 2 chunks
# 	Processing paper chunk 20ac767e1d3eb0035428fefe3ea83095a5e281db-abstract-chunk0000
# 	Processing paper chunk 20ac767e1d3eb0035428fefe3ea83095a5e281db-abstract-chunk0001
# Processing paper 20cc7f0676b5a01158a24595776debdaa1d5ed05
# 	Split into 1 chunks
# 	Processing paper chunk 20cc7f0676b5a01158a24595776debdaa1d5ed05-abstract-chunk0000
# Processing paper 2115420cb687ff41893be6750ac405a569c6fdb7
# 	Split into 1 chunks
# 	Processing paper chunk 2115420cb687ff41893be6750ac405a569c6fdb7-abstract-chunk0000
# Processing paper 21676eb20dbf95723efc1f5e3497f79c69c26c7d
# 	Split into 1 chunks
# 	Processing paper chunk 21676eb20dbf95723efc1f5e3497f79c69c26c7d-abstract-chunk0000
# Processing paper 21821eec41e9ab18fba67cb26b9baaa48a695f82
# 	Split into 1 chunks
# 	Processing paper chunk 21821eec41e9ab18fba67cb26b9baaa48a695f82-abstract-chunk0000
# Processing paper 21b7938e607c9d454e7341ef9f80fdd2c40cd887
# 	Split into 1 chunks
# 	Processing paper chunk 21b7938e607c9d454e7341ef9f80fdd2c40cd887-abstract-chunk0000
# Processing paper 21fabdc871352fbbaa049ef6c5f6b3beda288828
# 	Split into 1 chunks
# 	Processing paper chunk 21fabdc871352fbbaa049ef6c5f6b3beda288828-abstract-chunk0000
# Processing paper 225278c096c276dfe554a6ac075f4c66a231a893
# 	Split into 1 chunks
# 	Processing paper chunk 225278c096c276dfe554a6ac075f4c66a231a893-abstract-chunk0000
# Processing paper 226a42280f141a6ca553aadadb6c09f48a4819a6
# 	Split into 1 chunks
# 	Processing paper chunk 226a42280f141a6ca553aadadb6c09f48a4819a6-abstract-chunk0000
# Processing paper 226cec8b96ec5015d524b0d1f0d724a1dbd50f19
# 	Split into 2 chunks
# 	Processing paper chunk 226cec8b96ec5015d524b0d1f0d724a1dbd50f19-abstract-chunk0000
# 	Processing paper chunk 226cec8b96ec5015d524b0d1f0d724a1dbd50f19-abstract-chunk0001
# Processing paper 22dd9bd4ae43deebe114fde6efc0eea435daa118
# 	Split into 1 chunks
# 	Processing paper chunk 22dd9bd4ae43deebe114fde6efc0eea435daa118-abstract-chunk0000
# Processing paper 235ba3ca6e546e326d3cb7c3b57acfaeba11fcb6
# 	Split into 1 chunks
# 	Processing paper chunk 235ba3ca6e546e326d3cb7c3b57acfaeba11fcb6-abstract-chunk0000
# Processing paper 23d0bf524fc9065cfca07b532d0c57830a7db882
# 	Split into 1 chunks
# 	Processing paper chunk 23d0bf524fc9065cfca07b532d0c57830a7db882-abstract-chunk0000
# Processing paper 2420f2348b70b29d6981afa7749c955b6a44c427
# 	Split into 1 chunks
# 	Processing paper chunk 2420f2348b70b29d6981afa7749c955b6a44c427-abstract-chunk0000
# Processing paper 24a404ce812ba24a3fab1f21cd98d958a6faa330
# 	Split into 1 chunks
# 	Processing paper chunk 24a404ce812ba24a3fab1f21cd98d958a6faa330-abstract-chunk0000
# Processing paper 25597b0013367504ef5a011ee1e7e8257df2169c
# 	Split into 1 chunks
# 	Processing paper chunk 25597b0013367504ef5a011ee1e7e8257df2169c-abstract-chunk0000
# Processing paper 2583e14cba27d20dbc0f515f16cc887300c4bc47
# 	Split into 1 chunks
# 	Processing paper chunk 2583e14cba27d20dbc0f515f16cc887300c4bc47-abstract-chunk0000
# Processing paper 25f1255baa1766165c27df1c83ba84756766186d
# 	Split into 1 chunks
# 	Processing paper chunk 25f1255baa1766165c27df1c83ba84756766186d-abstract-chunk0000
# Processing paper 269e210507c2afe79c9f06809c7d001bbc0a8609
# 	Split into 2 chunks
# 	Processing paper chunk 269e210507c2afe79c9f06809c7d001bbc0a8609-abstract-chunk0000
# 	Processing paper chunk 269e210507c2afe79c9f06809c7d001bbc0a8609-abstract-chunk0001
# Processing paper 26b1ad2977b1593dac098e65577d8acef0009e99
# 	Split into 1 chunks
# 	Processing paper chunk 26b1ad2977b1593dac098e65577d8acef0009e99-abstract-chunk0000
# Processing paper 2718426d026cb1a1051e7fc42fc1471c765cf0d1
# 	Split into 1 chunks
# 	Processing paper chunk 2718426d026cb1a1051e7fc42fc1471c765cf0d1-abstract-chunk0000
# Processing paper 282da2a35d53ba9c1316cdbfca526d8e5afe67e5
# 	Split into 2 chunks
# 	Processing paper chunk 282da2a35d53ba9c1316cdbfca526d8e5afe67e5-abstract-chunk0000
# 	Processing paper chunk 282da2a35d53ba9c1316cdbfca526d8e5afe67e5-abstract-chunk0001
# Processing paper 2839090634de44777a3bf4a230dc701ff39bd9c4
# 	Split into 1 chunks
# 	Processing paper chunk 2839090634de44777a3bf4a230dc701ff39bd9c4-abstract-chunk0000
# Processing paper 28f19b2a73e2afe3e31092373aa4b60cf85e740d
# 	Split into 1 chunks
# 	Processing paper chunk 28f19b2a73e2afe3e31092373aa4b60cf85e740d-abstract-chunk0000
# Processing paper 293a90a3e769ffc7017d40795d75e73891d411ff
# 	Split into 1 chunks
# 	Processing paper chunk 293a90a3e769ffc7017d40795d75e73891d411ff-abstract-chunk0000
# Processing paper 29424566c408129f88859dcafc4813dad93391b9
# 	Split into 1 chunks
# 	Processing paper chunk 29424566c408129f88859dcafc4813dad93391b9-abstract-chunk0000
# Processing paper 297ff6f2c5dfeeef0f93bd242944324d865e0f61
# 	Split into 1 chunks
# 	Processing paper chunk 297ff6f2c5dfeeef0f93bd242944324d865e0f61-abstract-chunk0000
# Processing paper 2a2895fcdb1a465b690a9c7c36243d727974dd8d
# 	Split into 1 chunks
# 	Processing paper chunk 2a2895fcdb1a465b690a9c7c36243d727974dd8d-abstract-chunk0000
# Processing paper 2a94398578b5dd56d19d70eb09cbe75c4e1daa89
# 	Split into 1 chunks
# 	Processing paper chunk 2a94398578b5dd56d19d70eb09cbe75c4e1daa89-abstract-chunk0000
# Processing paper 2b424b0c22ce7d55d5fb3fe6ce1e4a28905f7266
# 	Split into 1 chunks
# 	Processing paper chunk 2b424b0c22ce7d55d5fb3fe6ce1e4a28905f7266-abstract-chunk0000
# Processing paper 2ba883a237b17a6f43e42cefc8157218e50a89a5
# 	Split into 1 chunks
# 	Processing paper chunk 2ba883a237b17a6f43e42cefc8157218e50a89a5-abstract-chunk0000
# Processing paper 2c2a6ddaf0b36f71ef8124fa6a4e30c457e71dcd
# 	Split into 1 chunks
# 	Processing paper chunk 2c2a6ddaf0b36f71ef8124fa6a4e30c457e71dcd-abstract-chunk0000
# Processing paper 2c5c892a97169f37b69fbbfec28f35a534d85443
# 	Split into 1 chunks
# 	Processing paper chunk 2c5c892a97169f37b69fbbfec28f35a534d85443-abstract-chunk0000
# Processing paper 2c970f3bcac332c228917058628bc397e4757c95
# 	Split into 1 chunks
# 	Processing paper chunk 2c970f3bcac332c228917058628bc397e4757c95-abstract-chunk0000
# Processing paper 2d5d5ba45ce49907e8a104b95b724a702112673b
# 	Split into 1 chunks
# 	Processing paper chunk 2d5d5ba45ce49907e8a104b95b724a702112673b-abstract-chunk0000
# Processing paper 2e19de9399fcddf7042b82e5143414fdaffe54fe
# 	Split into 1 chunks
# 	Processing paper chunk 2e19de9399fcddf7042b82e5143414fdaffe54fe-abstract-chunk0000
# Processing paper 2e33e5d35f9a8d5b6a2f4091c6e2d22cb1c70a24
# 	Split into 1 chunks
# 	Processing paper chunk 2e33e5d35f9a8d5b6a2f4091c6e2d22cb1c70a24-abstract-chunk0000
# Processing paper 2e570f74934f171bef8684ff3a3672bd65668b0c
# 	Split into 1 chunks
# 	Processing paper chunk 2e570f74934f171bef8684ff3a3672bd65668b0c-abstract-chunk0000
# Processing paper 2e6c6d723d695de9577681a54c66475873df6391
# 	Split into 1 chunks
# 	Processing paper chunk 2e6c6d723d695de9577681a54c66475873df6391-abstract-chunk0000
# Created 7411 nodes

# %%
kg.query("""
         MATCH (n)
         RETURN count(n) as nodeCount
         """)
# Out:
# [{'nodeCount': 59083}]

# %% [markdown]
# ### Create a vector index

# %%
kg.query("""
         CREATE VECTOR INDEX `abstract_chunks`
          FOR (c:Chunk) ON (c.textEmbedding)
          OPTIONS { indexConfig: {
            `vector.dimensions`: 1536,
            `vector.similarity_function`: 'cosine'
         }}
""")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 kg.query("""
#       2          CREATE VECTOR INDEX `abstract_chunks`
#       3           FOR (c:Chunk) ON (c.textEmbedding)
#       4           OPTIONS { indexConfig: {
#       5             `vector.dimensions`: 1536,
#       6             `vector.similarity_function`: 'cosine'
#       7          }}
#       8 """)
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:242, in Neo4jGraph.query(self, query, params)
#     240 with self._driver.session(database=self._database) as session:
#     241     try:
# --> 242         data = session.run(Query(text=query, timeout=self.timeout), params)
#     243         json_data = [r.data() for r in data]
#     244         if self.sanitize:
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/work/session.py:313, in Session.run(self, query, parameters, **kwargs)
#     311 bookmarks = self._get_bookmarks()
#     312 parameters = dict(parameters or {}, **kwargs)
# --> 313 self._auto_result._run(
#     314     query, parameters, self._config.database,
#     315     self._config.impersonated_user, self._config.default_access_mode,
#     316     bookmarks, self._config.notifications_min_severity,
#     317     self._config.notifications_disabled_categories,
#     318 )
#     320 return self._auto_result
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/work/result.py:181, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_categories)
#     179 self._pull()
#     180 self._connection.send_all()
# --> 181 self._attach()
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/work/result.py:301, in Result._attach(self)
#     299 if self._exhausted is False:
#     300     while self._attached is False:
# --> 301         self._connection.fetch_message()
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:849, in Bolt.fetch_message(self)
#     845 # Receive exactly one message
#     846 tag, fields = self.inbox.pop(
#     847     hydration_hooks=self.responses[0].hydration_hooks
#     848 )
# --> 849 res = self._process_message(tag, fields)
#     850 self.idle_since = monotonic()
#     851 return res
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:369, in Bolt5x0._process_message(self, tag, fields)
#     367 self._server_state_manager.state = self.bolt_states.FAILED
#     368 try:
# --> 369     response.on_failure(summary_metadata or {})
#     370 except (ServiceUnavailable, DatabaseUnavailable):
#     371     if self.pool:
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:245, in Response.on_failure(self, metadata)
#     243 handler = self.handlers.get("on_summary")
#     244 Util.callback(handler)
# --> 245 raise Neo4jError.hydrate(**metadata)
#
# ClientError: {code: Neo.ClientError.Schema.EquivalentSchemaRuleAlreadyExists} {message: An equivalent index already exists, 'Index( id=11, name='abstract_chunks', type='VECTOR', schema=(:Chunk {textEmbedding}), indexProvider='vector-2.0' )'.}

# %%
kg.query("SHOW INDEXES")
# Out:
# [{'id': 11,
#   'name': 'abstract_chunks',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'VECTOR',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['textEmbedding'],
#   'indexProvider': 'vector-2.0',
#   'owningConstraint': None,
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 33, 52, 774000000, tzinfo=<UTC>),
#   'readCount': 2},
#  {'id': 1,
#   'name': 'index_343aff4e',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'LOOKUP',
#   'entityType': 'NODE',
#   'labelsOrTypes': None,
#   'properties': None,
#   'indexProvider': 'token-lookup-1.0',
#   'owningConstraint': None,
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 37, 16, 996000000, tzinfo=<UTC>),
#   'readCount': 39406},
#  {'id': 2,
#   'name': 'index_f7700477',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'LOOKUP',
#   'entityType': 'RELATIONSHIP',
#   'labelsOrTypes': None,
#   'properties': None,
#   'indexProvider': 'token-lookup-1.0',
#   'owningConstraint': None,
#   'lastRead': None,
#   'readCount': 0},
#  {'id': 5,
#   'name': 'unique_author',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Author'],
#   'properties': ['author'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_author',
#   'lastRead': None,
#   'readCount': 0},
#  {'id': 9,
#   'name': 'unique_chunk',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['chunkId'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_chunk',
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 37, 37, 234000000, tzinfo=<UTC>),
#   'readCount': 7},
#  {'id': 3,
#   'name': 'unique_paper',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Paper'],
#   'properties': ['paperId'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_paper',
#   'lastRead': neo4j.time.DateTime(2024, 3, 31, 12, 6, 18, 572000000, tzinfo=<UTC>),
#   'readCount': 78738},
#  {'id': 7,
#   'name': 'unique_venue',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'RANGE',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Venue'],
#   'properties': ['venueId'],
#   'indexProvider': 'range-1.0',
#   'owningConstraint': 'unique_venue',
#   'lastRead': None,
#   'readCount': 0}]

# %% [markdown]
# ### Calculate embedding vectors for chunks and populate index
# - This query calculates the embedding vector and stores it as a property called `textEmbedding` on each `Chunk` node.

# %%
kg.query("""
    MATCH (chunk:Chunk) WHERE chunk.textEmbedding IS NULL
    WITH chunk, genai.vector.encode(
      chunk.text,
      "OpenAI",
      {
        token: $openAiApiKey
      }) AS vector
    CALL db.create.setNodeVectorProperty(chunk, "textEmbedding", vector)
    """,
    params={"openAiApiKey":OPENAI_API_KEY} )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[249], line 1
# ----> 1 kg.query("""
#       2     MATCH (chunk:Chunk) WHERE chunk.textEmbedding IS NULL
#       3     WITH chunk, genai.vector.encode(
#       4       chunk.text,
#       5       "OpenAI",
#       6       {
#       7         token: $openAiApiKey
#       8       }) AS vector
#       9     CALL db.create.setNodeVectorProperty(chunk, "textEmbedding", vector)
#      10     """,
#      11     params={"openAiApiKey":OPENAI_API_KEY} )
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:242, in Neo4jGraph.query(self, query, params)
#     240 with self._driver.session(database=self._database) as session:
#     241     try:
# --> 242         data = session.run(Query(text=query, timeout=self.timeout), params)
#     243         json_data = [r.data() for r in data]
#     244         if self.sanitize:
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/work/session.py:313, in Session.run(self, query, parameters, **kwargs)
#     311 bookmarks = self._get_bookmarks()
#     312 parameters = dict(parameters or {}, **kwargs)
# --> 313 self._auto_result._run(
#     314     query, parameters, self._config.database,
#     315     self._config.impersonated_user, self._config.default_access_mode,
#     316     bookmarks, self._config.notifications_min_severity,
#     317     self._config.notifications_disabled_categories,
#     318 )
#     320 return self._auto_result
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/work/result.py:181, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_categories)
#     179 self._pull()
#     180 self._connection.send_all()
# --> 181 self._attach()
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/work/result.py:301, in Result._attach(self)
#     299 if self._exhausted is False:
#     300     while self._attached is False:
# --> 301         self._connection.fetch_message()
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:846, in Bolt.fetch_message(self)
#     843     return 0, 0
#     845 # Receive exactly one message
# --> 846 tag, fields = self.inbox.pop(
#     847     hydration_hooks=self.responses[0].hydration_hooks
#     848 )
#     849 res = self._process_message(tag, fields)
#     850 self.idle_since = monotonic()
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:72, in Inbox.pop(self, hydration_hooks)
#      71 def pop(self, hydration_hooks):
# ---> 72     self._buffer_one_chunk()
#      73     try:
#      74         size, tag = self._unpacker.unpack_structure_header()
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:51, in Inbox._buffer_one_chunk(self)
#      48 while True:
#      49     while chunk_size == 0:
#      50         # Determine the chunk size and skip noop
# ---> 51         receive_into_buffer(self._socket, self._buffer, 2)
#      52         chunk_size = self._buffer.pop_u16()
#      53         if chunk_size == 0:
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#     324 with memoryview(buffer.data) as view:
#     325     while buffer.used < end:
# --> 326         n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#     327         if n == 0:
#     328             raise OSError("No data")
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#     492 def recv_into(self, buffer, nbytes):
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
# File ~/Library/Caches/pypoetry/virtualenvs/search-bulk-OtBC7O7--py3.11/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#     466 def _wait_for_io(self, func, *args, **kwargs):
#     467     if self._deadline is None:
# --> 468         return func(*args, **kwargs)
#     469     timeout = self._socket.gettimeout()
#     470     deadline_timeout = self._deadline.to_timeout()
#
# KeyboardInterrupt:

# %%
kg.refresh_schema()
print(kg.schema)
# Out:
# Node properties are the following:
# Paper {openAccessPdfStatus: STRING, fieldsOfStudy: LIST, publicationDate: STRING, citationCount: INTEGER, influentialCitationCount: INTEGER, isOpenAccess: BOOLEAN, openAccessPdfUrl: STRING, url: STRING, venue: STRING, year: INTEGER, referenceCount: INTEGER, externalIdDoi: STRING, corpusId: INTEGER, title: STRING, externalIdMag: STRING, externalIdCorpus: INTEGER, paperId: STRING, publicationTypes: LIST, abstract: STRING},Author {name: STRING, authorId: STRING},Chunk {textEmbedding: LIST, source: STRING, title: STRING, chunkId: STRING, chunkSeqId: INTEGER, text: STRING}
# Relationship properties are the following:
#
# The relationships are the following:

# %% [markdown]
# ### Use similarity search to find relevant chunks

# %% [markdown]
# - Setup a help function to perform similarity search using the vector index

# %%
def neo4j_vector_search(question):
  """Search for similar nodes using the Neo4j vector index"""
  vector_search_query = """
    WITH genai.vector.encode(
      $question,
      "OpenAI",
      {
        token: $openAiApiKey
      }) AS question_embedding
    CALL db.index.vector.queryNodes($index_name, $top_k, question_embedding) yield node, score
    RETURN score, node.text AS text
  """
  similar = kg.query(vector_search_query,
                     params={
                      'question': question,
                      'openAiApiKey':OPENAI_API_KEY,
                      'index_name':VECTOR_INDEX_NAME,
                      'top_k': 10})
  return similar

# %% [markdown]
# - Ask a question!

# %%
search_results = neo4j_vector_search(
    'sensitive magnetometers are Magnetocardiography .'
)

# %%
search_results[0]
# Out:
# {'score': 0.9355030059814453,
#  'text': 'Presently, among the most demanding applications for highly sensitive magnetometers are Magnetocardiography (MCG) and Magnetoencephalography (MEG), where sensitivities of around 1pT.Hz-1/2 and 1fT.Hz-1/2 are required. Cryogenic Superconducting Quantum Interference Devices (SQUIDs) are currently used as the magnetometers. However, there has been some recent work on replacing these devices with magnetometers based on atomic spectroscopy and operating at room temperature. There are demonstrations of MCG and MEG signals measured using atomic spectroscopy These atomic magnetometers are based on chip-scale microfabricated components. In this paper we discuss the prospects of using photonic crystal optical fibres or hollow core fibres (HCFs) loaded with Rb vapour in atomic magnetometer systems. We also consider new components for magnetometers based on mode-locked semiconductor lasers for measuring magnetic field via coherent population trapping (CPT) in Rb loaded HCFs.'}

# %% [markdown]
# ### Set up a LangChain RAG workflow to chat with the form

# %%
neo4j_vector_store = Neo4jVector.from_existing_graph(
    embedding=OpenAIEmbeddings(),
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    index_name=VECTOR_INDEX_NAME,
    node_label=VECTOR_NODE_LABEL,
    text_node_properties=[VECTOR_SOURCE_PROPERTY],
    embedding_node_property=VECTOR_EMBEDDING_PROPERTY,
)

# %%
retriever = neo4j_vector_store.as_retriever()

# %% [markdown]
# - Set up a RetrievalQAWithSourcesChain to carry out question answering
# - You can check out the LangChain documentation for this chain [here](https://api.python.langchain.com/en/latest/chains/langchain.chains.qa_with_sources.retrieval.RetrievalQAWithSourcesChain.html)

# %%
chain = RetrievalQAWithSourcesChain.from_chain_type(
    ChatOpenAI(temperature=0),
    chain_type="stuff",
    retriever=retriever
)

# %%
def prettychain(question: str) -> str:
    """Pretty print the chain's response to a question"""
    response = chain({"question": question},
        return_only_outputs=True,)
    print(textwrap.fill(response['answer'], 60))

# %% [markdown]
# - Ask a question!

# %%
question = "Explain me about magnetometers are Magnetocardiography "

# %%
prettychain(question)
# Out:
# Magnetometers are used in Magnetocardiography (MCG) and
# Magnetoencephalography (MEG) applications, requiring high
# sensitivities. Cryogenic Superconducting Quantum
# Interference Devices (SQUIDs) are currently used as
# magnetometers, but there is ongoing research on replacing
# them with atomic spectroscopy-based magnetometers operating
# at room temperature. These atomic magnetometers are based on
# chip-scale microfabricated components. There are also
# demonstrations of MCG and MEG signals measured using atomic
# spectroscopy. Additionally, there are prospects of using
# photonic crystal optical fibers or hollow core fibers (HCFs)
# loaded with Rb vapor in atomic magnetometer systems, as well
# as new components based on mode-locked semiconductor lasers
# for measuring magnetic fields via coherent population
# trapping (CPT) in Rb loaded HCFs.

# %%
prettychain("Where is Netapp headquartered?")

# %%
prettychain("""
    Tell me about Netapp.
    Limit your answer to a single sentence.
""")

# %%
prettychain("""
    Tell me about Apple.
    Limit your answer to a single sentence.
""")

# %%
prettychain("""
    Tell me about Apple.
    Limit your answer to a single sentence.
    If you are unsure about the answer, say you don't know.
""")

# %% [markdown]
# ### Ask you own question!
# - Add your own question to the call to prettychain below to find out more about NetApp
# - Here is NetApp's website if you want some inspiration: https://www.netapp.com/

# %%
prettychain("""
    ADD YOUR OWN QUESTION HERE
""")
